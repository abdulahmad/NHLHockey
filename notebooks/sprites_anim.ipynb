# %% [markdown]
# ## Functions

# %% [markdown]
# ### Parse Frames & Sprites Functions

# %%
# Returns Parser with Frame and Sprite objects

import struct
from dataclasses import dataclass
from typing import List, Optional, Tuple
import os

@dataclass
class Sprite:
    y_pos: int
    x_pos: int
    size_tab: int
    tile_id: int
    palette_id: int
    hex_data: bytes
    
    # Calculated properties
    size_index: int
    tile_count: int
    dimensions: Tuple[int, int]
    starting_tile_offset: int
    width: int  # Added: width in tiles
    height: int  # Added: height in tiles
    pixel_width: int  # Added: width in pixels
    pixel_height: int  # Added: height in pixels
    priority: int  # Added: priority flag
    vflip: int  # Added: vertical flip flag
    hflip: int  # Added: horizontal flip flag

@dataclass
class Frame:
    sprstratt: int
    sprstrhot: int
    x_hot: int
    y_hot: int
    num_sprites: int
    sprites: List[Sprite]
    hex_data: bytes
    
class SpritesAnimParser:
    # Sprite size lookup table
    SIZE_TABLE = {
        0x0: (1, 1, 1),   # tiles, width, height
        0x1: (2, 1, 2),
        0x2: (3, 1, 3),
        0x3: (4, 1, 4),
        0x4: (2, 2, 1),
        0x5: (4, 2, 2),
        0x6: (6, 2, 3),
        0x7: (8, 2, 4),
        0x8: (3, 3, 1),
        0x9: (6, 3, 2),
        0xA: (9, 3, 3),
        0xB: (12, 3, 4),
        0xC: (4, 4, 1),
        0xD: (8, 4, 2),
        0xE: (12, 4, 3),
        0xF: (16, 4, 4),
    }
    
    # Tile size constants (8x8 pixels per tile)
    TILE_WIDTH = 8
    TILE_HEIGHT = 8
    
    def __init__(self, filename):
        self.filename = filename
        with open(filename, 'rb') as f:
            self.data = f.read()
        
        self.parse()
    
    def read_word(self, offset):
        """Read a 2-byte word (big-endian)"""
        return struct.unpack('>H', self.data[offset:offset+2])[0]
    
    def read_signed_word(self, offset):
        """Read a 2-byte signed word (big-endian)"""
        return struct.unpack('>h', self.data[offset:offset+2])[0]
    
    def parse(self):
        # Parse header
        signature = self.data[0:2]
        if signature != b'AA':
            if self.data[0:2].decode('ascii', errors='ignore') != 'AA':
                raise ValueError(f"Invalid file signature: {signature.hex()}")
        
        self.num_frames = self.read_word(0x02) + 1  # 0-based, so add 1
        
        # Check for frame signature in header
        if self.data[0x06:0x08] != b'SS' and self.data[0x06:0x08].decode('ascii', errors='ignore') != 'SS':
            raise ValueError(f"Expected frame signature 'SS' at offset 0x06")
        
        # Parse frames
        self.frames = []
        offset = 0x06  # First frame starts at 0x06
        
        # First pass: parse all frames
        for i in range(self.num_frames):
            frame, offset = self.parse_frame(offset)
            self.frames.append(frame)
        
        # Check for end of frames marker
        if self.data[offset:offset+2] != b'CC' and self.data[offset:offset+2].decode('ascii', errors='ignore') != 'CC':
            raise ValueError(f"Expected end of frames marker 'CC' at offset {offset:x}")
        
        # Mark the position of the last frame signature (CC)
        last_frame_signature_offset = offset
        
        # Tileset Data starts 2 bytes after the last frame signature
        tileset_data_start_offset = last_frame_signature_offset + 2
        
        # Read the tileset data size (first two bytes after CC signature)
        tileset_data_size = self.read_word(tileset_data_start_offset)
        
        # The actual tileset data starts after the size value
        self.tileset_data_offset = tileset_data_start_offset + 2
        
        # Palette Data Start = first two bytes after last frame signature + Tileset Data offset
        self.palette_data_offset = tileset_data_start_offset + tileset_data_size
        
        # Second pass: update sprite tile offsets now that we know the tileset data offset
        for frame in self.frames:
            for sprite in frame.sprites:
                # Recalculate starting tile offset with the tileset data offset
                tile_offset = ((sprite.tile_id & 0x07FF) | ((sprite.size_tab & 0xF000) >> 1)) * 32
                sprite.starting_tile_offset = self.tileset_data_offset + tile_offset
    
    def parse_frame(self, offset):
        """Parse a single frame starting at the given offset"""
        frame_start = offset
        
        # Check frame signature
        frame_sig = self.data[offset:offset+2]
        if frame_sig != b'SS' and frame_sig.decode('ascii', errors='ignore') != 'SS':
            raise ValueError(f"Invalid frame signature at offset {offset:x}: {frame_sig.hex()}")
        
        # Read frame header values
        sprstratt = self.read_word(offset + 0x0A)
        sprstrhot = self.read_word(offset + 0x0C)
        x_hot = self.read_signed_word(offset + 0x18)
        y_hot = self.read_signed_word(offset + 0x1A)
        num_sprites = self.read_word(offset + 0x24) + 1  # 0-based
        
        # Parse sprites
        sprites = []
        sprite_offset = offset + 0x26
        
        for _ in range(num_sprites):
            sprite, sprite_offset = self.parse_sprite(sprite_offset)
            sprites.append(sprite)
        
        frame_end = sprite_offset
        frame_hex_data = self.data[frame_start:frame_end]
        
        frame = Frame(
            sprstratt=sprstratt,
            sprstrhot=sprstrhot,
            x_hot=x_hot,
            y_hot=y_hot,
            num_sprites=num_sprites,
            sprites=sprites,
            hex_data=frame_hex_data
        )
        
        return frame, frame_end
    
    def parse_sprite(self, offset):
        """Parse a single sprite starting at the given offset"""
        sprite_start = offset
        
        y_pos = self.read_signed_word(offset)
        size_tab = self.read_word(offset + 2)
        tile_id = self.read_word(offset + 4)
        x_pos = self.read_signed_word(offset + 6)
        
        # Extract size index
        size_index = (size_tab >> 8) & 0x0F
        
        # Look up sprite dimensions and tile count
        if size_index in self.SIZE_TABLE:
            tile_count, width, height = self.SIZE_TABLE[size_index]
            dimensions = (width, height)
        else:
            tile_count = 0
            width = 0
            height = 0
            dimensions = (0, 0)
        
        # Calculate palette ID (bit 14 of tile_id)
        palette_id = (tile_id >> 13) & 0x03
        
        # Calculate starting tile offset (will be updated after we know tileset data offset)
        tile_offset = ((tile_id & 0x07FF) | ((size_tab & 0xF000) >> 1)) * 32

         # Extract priority, vflip, and hflip from tile_id
        priority = (tile_id >> 12) & 1
        vflip = (tile_id >> 12) & 1
        hflip = (tile_id >> 13) & 1
        
        sprite_end = offset + 8
        sprite_hex_data = self.data[sprite_start:sprite_end]
        
        # Calculate pixel dimensions
        pixel_width = width * self.TILE_WIDTH
        pixel_height = height * self.TILE_HEIGHT
        
        sprite = Sprite(
            y_pos=y_pos,
            x_pos=x_pos,
            size_tab=size_tab,
            tile_id=tile_id,
            palette_id=palette_id,
            hex_data=sprite_hex_data,
            size_index=size_index,
            tile_count=tile_count,
            dimensions=dimensions,
            starting_tile_offset=tile_offset,  # This will be updated later
            width=width,
            height=height,
            pixel_width=pixel_width,
            pixel_height=pixel_height,
            priority=priority,  # Added
            vflip=vflip,        # Added
            hflip=hflip         # Added
        )
        
        return sprite, sprite_end
    
    def print_analysis(self):
        """Print the analysis of the parsed file"""
        print(f"Analysis of: {os.path.basename(self.filename)}")
        print("=" * 50)
        print(f"Total number of frames: {self.num_frames}")
        print(f"Tileset Data offset: 0x{self.tileset_data_offset:04X}")
        print(f"Palette Data offset: 0x{self.palette_data_offset:04X}")
        print()
        
        for i, frame in enumerate(self.frames):
            print(f"Frame {i}:")
            print(f"  SprStrAtt: 0x{frame.sprstratt:04X}")
            print(f"  SprStrHot: 0x{frame.sprstrhot:04X}")
            print(f"  X Hot: {frame.x_hot}")
            print(f"  Y Hot: {frame.y_hot}")
            print(f"  Number of sprites: {frame.num_sprites}")
            print(f"  Frame Hex Data: {frame.hex_data.hex().upper()}")
            print()
            
            for j, sprite in enumerate(frame.sprites):
                print(f"  Sprite {j}:")
                print(f"    Size: {sprite.width}x{sprite.height} tiles ({sprite.pixel_width}x{sprite.pixel_height} pixels)")
                print(f"    Number of tiles: {sprite.tile_count}")
                print(f"    Starting tile offset: 0x{sprite.starting_tile_offset:04X}")
                print(f"    X Position: {sprite.x_pos}")
                print(f"    Y Position: {sprite.y_pos}")
                print(f"    Tile ID: 0x{sprite.tile_id:04X}")
                print(f"    Palette ID: {sprite.palette_id}")
                print(f"    Priority: {sprite.priority}")  # Added
                print(f"    Vertical Flip (vflip): {sprite.vflip}")  # Added
                print(f"    Horizontal Flip (hflip): {sprite.hflip}")  # Added
                print(f"    Sprite Hex Data: {sprite.hex_data.hex().upper()}")
                print()
            print("-" * 40)
            print()

# Helper function to debug file structure
def debug_file_structure(filename, max_bytes=256):
    """Debug function to examine the file structure"""
    with open(filename, 'rb') as f:
        data = f.read(max_bytes)
    
    print(f"First {max_bytes} bytes of {os.path.basename(filename)}:")
    print("Offset | Hex Values | ASCII")
    print("-" * 50)
    
    for i in range(0, min(len(data), max_bytes), 16):
        hex_values = ' '.join([f'{b:02X}' for b in data[i:i+16]])
        ascii_values = ''.join([chr(b) if 32 <= b <= 126 else '.' for b in data[i:i+16]])
        print(f'{i:06X} | {hex_values:<48} | {ascii_values}')

# Main parsing function
def analyze_sprites_file(filename):
    """
    Analyze a sprites.anim file and display the results
    
    Args:
        filename: Path to the sprites.anim file
    """
    try:
        # First, let's examine the file structure
        debug_file_structure(filename, 128)
        print("\n" + "="*50 + "\n")
        
        # Now parse the file
        parser = SpritesAnimParser(filename)
        parser.print_analysis()
        return parser
    except Exception as e:
        print(f"Error analyzing file: {e}")
        import traceback
        traceback.print_exc()
        return None

# %% [markdown]
# ### Decode Genesis Tiles as PNG Functions

# %%
# Retruns an Image
# Required input parameters:
# - tile_hex_string: Hexadecimal string representing the sprite's tile data.
# - tiles_wide: Number of tiles horizontally in the sprite.
# - tiles_high: Number of tiles vertically in the sprite.
# - palette_hex_string: Hexadecimal string representing the color palette.

import binascii
from PIL import Image
import io  # Needed for displaying in some notebook environments

def decode_genesis_sprite(tile_hex_string, tiles_wide, tiles_high, palette_hex_string):
    """
    Decodes Sega Genesis 4bpp linear tile data into a Pillow Image object.

    Assumes tiles in the hex string are stored in column-major order.

    Args:
        tile_hex_string (str): A string containing space-separated hex bytes
                               representing the 4bpp tile data.
        tiles_wide (int): The number of tiles horizontally in the sprite.
        tiles_high (int): The number of tiles vertically in the sprite.
        palette_hex_string (str): A string containing space-separated 6-digit
                                  RRGGBB hex color values for the 16-color palette.

    Returns:
        PIL.Image.Image: A Pillow Image object in 'P' (paletted) mode,
                         or None if a critical error occurred.

    Raises:
        ValueError: If tile_hex_string contains invalid hex data or if the
                    amount of data doesn't match the expected size.
    """
    # --- Configuration (Constants for Genesis 8x8 4bpp tiles) ---
    TILE_WIDTH_PX = 8
    TILE_HEIGHT_PX = 8
    BPP = 4 # Bits per pixel

    # 1. Parse Palette
    palette_colors_hex = palette_hex_string.split()
    if len(palette_colors_hex) < 16:
        print(f"Warning: Provided palette has {len(palette_colors_hex)} colors, expected 16. Padding with black.")
        palette_colors_hex.extend(["000000"] * (16 - len(palette_colors_hex)))

    # Convert hex palette to list of RGB tuples using the helper
    palette_rgb = [_hex_rgb_to_tuple(hex_col) for hex_col in palette_colors_hex[:16]] # Take only first 16

    # Flatten palette for Pillow (R1, G1, B1, R2, G2, B2, ...)
    flat_palette = [component for color in palette_rgb for component in color]
    # Pad the Pillow palette to 768 bytes (256 colors * 3 channels)
    flat_palette.extend([0] * (768 - len(flat_palette)))

    # 2. Parse Tile Data
    # Remove whitespace and newlines before converting
    tile_data_hex_clean = "".join(tile_hex_string.split())
    try:
        tile_data_bytes = binascii.unhexlify(tile_data_hex_clean)
    except binascii.Error as e:
        raise ValueError(f"Error converting tile hex data to bytes: {e}. Invalid hex data.") from e

    # Verify data size
    bytes_per_tile = (TILE_WIDTH_PX * TILE_HEIGHT_PX * BPP) // 8
    num_tiles = tiles_wide * tiles_high
    expected_bytes = num_tiles * bytes_per_tile

    if len(tile_data_bytes) < expected_bytes:
         raise ValueError(f"Input data is too short! Expected {expected_bytes} bytes for a {tiles_wide}x{tiles_high} sprite, got {len(tile_data_bytes)} bytes.")
    elif len(tile_data_bytes) > expected_bytes:
         print(f"Warning: Input data is longer than expected ({len(tile_data_bytes)} vs {expected_bytes}). Using first {expected_bytes} bytes.")
         tile_data_bytes = tile_data_bytes[:expected_bytes]


    # 3. Create Image and Decode Pixels (Assuming Column-Major Order in Source Data)
    img_width = tiles_wide * TILE_WIDTH_PX
    img_height = tiles_high * TILE_HEIGHT_PX
    img = Image.new('P', (img_width, img_height))
    img.putpalette(flat_palette)

    # Iterate through the *output grid positions* (column by column)
    for tile_col in range(tiles_wide):
        for tile_row in range(tiles_high):
            # Calculate the index in the *linear source data* based on column-major assumption
            linear_tile_index = tile_col * tiles_high + tile_row

            # This check should be redundant due to the size check above, but safe to keep
            if linear_tile_index >= num_tiles:
                print(f"Error: Calculated linear tile index {linear_tile_index} is out of bounds (max {num_tiles-1}). Skipping tile.")
                continue

            tile_start_byte = linear_tile_index * bytes_per_tile

            # --- Decode the pixels for this specific tile ---
            tile_pixels = [] # Palette indices for this 8x8 tile
            for i in range(bytes_per_tile):
                byte_offset = tile_start_byte + i
                byte_val = tile_data_bytes[byte_offset]
                pixel1_index = (byte_val >> 4) & 0x0F # High nibble
                pixel2_index = byte_val & 0x0F        # Low nibble
                tile_pixels.append(pixel1_index)
                tile_pixels.append(pixel2_index)
            # --- Finished decoding pixels for this tile ---

            # --- Place these tile pixels onto the main image canvas ---
            start_x = tile_col * TILE_WIDTH_PX
            start_y = tile_row * TILE_HEIGHT_PX

            for y_in_tile in range(TILE_HEIGHT_PX):
                for x_in_tile in range(TILE_WIDTH_PX):
                    pixel_index_in_tile = y_in_tile * TILE_WIDTH_PX + x_in_tile
                    palette_idx = tile_pixels[pixel_index_in_tile]

                    # Check index validity against palette size (should be 0-15)
                    if palette_idx >= len(palette_rgb): # len(palette_rgb) is 16
                        print(f"Warning: Pixel data uses palette index {palette_idx}, which is invalid for a 16-color palette. Using index 0.")
                        palette_idx = 0

                    img.putpixel((start_x + x_in_tile, start_y + y_in_tile), palette_idx)

    return img

def _hex_rgb_to_tuple(hex_rgb):
    """Converts a 6-digit hex RGB string (e.g., '90FCFC') to an RGB tuple (0-255)."""
    hex_rgb = hex_rgb.lstrip('#') # Remove leading # if present
    if len(hex_rgb) != 6:
        # Use warning instead of print for library-like function
        import warnings
        warnings.warn(f"Invalid hex color length '{hex_rgb}'. Using black (0,0,0).")
        return (0, 0, 0)
    try:
        r = int(hex_rgb[0:2], 16)
        g = int(hex_rgb[2:4], 16)
        b = int(hex_rgb[4:6], 16)
        return (r, g, b)
    except ValueError:
        import warnings
        warnings.warn(f"Invalid hex color value '{hex_rgb}'. Using black (0,0,0).")
        return (0, 0, 0)

# %% [markdown]
# ### Export Sprites To PNG Function

# %%
# Function to export sprites to PNG files
# Required input parameters:
# - parser: SpritesAnimParser object containing parsed sprite data
# - output_dir: Directory where PNG files will be saved (default: 'frames_output')
# - palette_hex: Hex string representing the color palette (default provided)

import os

#90FCFC FCFCFC D8FCFC D8D8D8 000000 B4B4B4 6C6C6C 484848 ECC8C8 FC9090 D8486C 486CD8 D8B424 6C90FC 242424 FCFCFC 
#90FCFC D8D8D8 909090 484848 242424 D89000 B46C00 000000 242490 00006C 244800 002400 B44800 6C0000 B46C6C 6C4824 
#90FCFC 242424 000000 000000 242424 242424 D89090 B46C6C D84800 FCB400 FCFCFC D8D8D8 FCFCFC B4B4B4 D89048 4890B4 
#90FCFC 242424 000000 242400 244824 246C48 D89090 B46C6C D86C00 FC9024 D8D8D8 249024 24B424 246C24 D89048 4890B4 

def export_sprites_to_png(parser, output_dir='frames_output', palette_hex="90FCFC 242424 000000 000000 242424 242424 D89090 B46C6C D84800 FCB400 FCFCFC D8D8D8 FCFCFC B4B4B4 D89048 4890B4"):
    """
    Export all sprites from parsed data to PNG files using the existing decode_genesis_sprite function.
    
    Args:
        parser: SpritesAnimParser object with parsed data
        output_dir: Base directory for output
        palette_hex: Hex string of palette colors
    """
    # Create base output directory
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Process each frame
    for frame_idx, frame in enumerate(parser.frames):
        # Create frame directory
        frame_dir = os.path.join(output_dir, f'frame_{frame_idx}')
        if not os.path.exists(frame_dir):
            os.makedirs(frame_dir)
        
        #print(f"Processing frame {frame_idx}...")
        
        # Process each sprite in the frame
        for sprite_idx, sprite in enumerate(frame.sprites):
            # Extract tile data for this sprite
            tile_data = []
            for tile_idx in range(sprite.tile_count):
                tile_offset = sprite.starting_tile_offset + (tile_idx * 32)
                tile_bytes = parser.data[tile_offset:tile_offset + 32]
                tile_data.extend(tile_bytes)
            
            # Convert to hex string
            tile_hex_string = ''.join([f'{b:02X}' for b in tile_data])
            
            # Call your existing function to create sprite image
            sprite_image = decode_genesis_sprite(
                tile_hex_string,
                sprite.width,
                sprite.height,
                palette_hex
            )
            
            # Save sprite image
            filename = f'sprite_{sprite_idx}.png'
            filepath = os.path.join(frame_dir, filename)
            sprite_image.save(filepath)
            
            #print(f"  Saved sprite {sprite_idx} to {filepath}")
    
    #print(f"\nExport complete! All sprites saved to {output_dir}")

# %% [markdown]
# ### Combine Frame Sprites As 1 PNG Function

# %%
# Functions to create a frame image from multiple sprites
from PIL import Image
import os
import math

# --- Constants ---
TILE_SIZE = 8  # Standard Sega Genesis tile size is 8x8 pixels

# --- Helper Function ---
def calculate_sprite_bounds(sprite_info):
    """Calculates sprite pixel dimensions and bounding box relative to the hotspot."""
    width_px = sprite_info["size_tiles"][0] * TILE_SIZE
    height_px = sprite_info["size_tiles"][1] * TILE_SIZE

    # Top-left corner relative to hotspot
    top_left_x = sprite_info["pos_x"]
    top_left_y = sprite_info["pos_y"]

    # Bottom-right corner relative to hotspot
    bottom_right_x = top_left_x + width_px
    bottom_right_y = top_left_y + height_px

    return {
        "width_px": width_px,
        "height_px": height_px,
        "top_left_x": top_left_x,
        "top_left_y": top_left_y,
        "bottom_right_x": bottom_right_x,
        "bottom_right_y": bottom_right_y,
    }

# --- Core Frame Creation Function ---
def create_frame_image(frame_data, sprite_base_path, sprite_file_template, output_filename):
    """
    Combines individual sprite PNGs into a single frame image based on frame data.

    Args:
        frame_data (dict): Dictionary containing data for a single frame.
                           Expected keys: 'frame_index', 'hotspot_x', 'hotspot_y',
                           'sprites' (list of sprite info dicts).
                           Each sprite info dict needs: 'index', 'size_tiles', 'pos_x', 'pos_y'.
        sprite_base_path (str): The directory where the individual sprite PNGs are located.
        sprite_file_template (str): A format string for sprite filenames,
                                    e.g., "sprite_{index}.png".
        output_filename (str): The full path and filename for the final combined image.

    Returns:
        bool: True if the frame image was created successfully, False otherwise.
    """
    frame_index = frame_data.get("frame_index", "Unknown")
    print(f"\n--- Processing Frame {frame_index} ---")

    if not frame_data.get("sprites"):
        print(f"  No sprites defined for frame {frame_index}. Skipping.")
        # Optionally create an empty or 1x1 transparent image if needed
        # Example: Image.new('RGBA', (1, 1), (0, 0, 0, 0)).save(output_filename)
        return True  # Consider it success if there's nothing to do

    if len(frame_data["sprites"]) == 1:
        print(f"  Only one sprite defined for frame {frame_index}. Skipping.")
        return True  # Exit if there's only one sprite

    # 1. Calculate overall bounding box to determine canvas size
    min_x = float('inf')
    min_y = float('inf')
    max_x = float('-inf')
    max_y = float('-inf')

    sprite_details = [] # Store calculated details and image objects
    has_errors = False

    print("  Loading and analyzing sprites...")
    for sprite_info in frame_data["sprites"]:
        sprite_index = sprite_info["index"]
        sprite_filename_only = sprite_file_template.format(index=sprite_index)
        sprite_full_path = os.path.join(sprite_base_path, sprite_filename_only)

        if not os.path.exists(sprite_full_path):
            print(f"  Error: Sprite file not found: {sprite_full_path}")
            has_errors = True
            continue # Skip this sprite, maybe continue with others? Or return False immediately?

        try:
            img = Image.open(sprite_full_path).convert("RGBA") # Ensure RGBA for transparency
        except Exception as e:
            print(f"  Error opening or converting sprite {sprite_full_path}: {e}")
            has_errors = True
            continue

        bounds = calculate_sprite_bounds(sprite_info)

        # Check if loaded image size matches expected size
        if img.width != bounds["width_px"] or img.height != bounds["height_px"]:
            print(f"  Warning: Sprite {sprite_filename_only} dimensions ({img.width}x{img.height}) "
                  f"do not match expected size ({bounds['width_px']}x{bounds['height_px']}) "
                  f"based on tile data.")

        sprite_details.append({
            "info": sprite_info,
            "bounds": bounds,
            "image": img
        })

        # Update overall min/max coordinates (relative to hotspot)
        min_x = min(min_x, bounds["top_left_x"])
        min_y = min(min_y, bounds["top_left_y"])
        max_x = max(max_x, bounds["bottom_right_x"])
        max_y = max(max_y, bounds["bottom_right_y"])

        # print(f"    Sprite {sprite_index} ({sprite_filename_only}): "
        #       f"Size={bounds['width_px']}x{bounds['height_px']}, "
        #       f"PosRelHotspot=({sprite_info['pos_x']}, {sprite_info['pos_y']}), "
        #       f"BoundsRelHotspot=[{bounds['top_left_x']}:{bounds['bottom_right_x']}, {bounds['top_left_y']}:{bounds['bottom_right_y']}]")

    if has_errors:
        print(f"  Errors encountered while loading sprites for frame {frame_index}. Frame not created.")
        return False

    if not sprite_details: # Should only happen if errors occurred and we continued
         print(f"  No valid sprites found to process for frame {frame_index}.")
         return False

    # 2. Determine canvas size and the offset for pasting
    # Handle cases where max == min (e.g., single point) by ensuring minimum 1 pixel size
    canvas_width = max(1, max_x - min_x)
    canvas_height = max(1, max_y - min_y)

    offset_x = -min_x
    offset_y = -min_y

    print(f"  Overall Bounds Rel Hotspot: X=[{min_x}, {max_x}], Y=[{min_y}, {max_y}]")
    print(f"  Calculated Canvas Size: {canvas_width} x {canvas_height}")
    print(f"  Placement Offset (Hotspot's pos on canvas): ({offset_x}, {offset_y})")

    # 3. Create the canvas
    final_image = Image.new('RGBA', (canvas_width, canvas_height), (0, 0, 0, 0))

    # 4. Paste sprites onto the canvas
    print(f"  Pasting {len(sprite_details)} sprites onto canvas...")
    for details in sprite_details:
        sprite_img = details["image"]
        sprite_info = details["info"]

        paste_x = sprite_info["pos_x"] + offset_x
        paste_y = sprite_info["pos_y"] + offset_y

        # print(f"    Pasting sprite {details['info']['index']} at canvas coordinates: ({paste_x}, {paste_y})")
        final_image.paste(sprite_img, (paste_x, paste_y), sprite_img)

    # 5. Save the final image
    try:
        # Ensure output directory exists
        output_dir = os.path.dirname(output_filename)
        if output_dir: # Only create if path contains a directory part
            os.makedirs(output_dir, exist_ok=True)

        final_image.save(output_filename)
        print(f"  Successfully combined sprites into {output_filename}")
        # Optional: Print hotspot info relative to canvas
        # frame_hotspot_x = frame_data['hotspot_x']
        # frame_hotspot_y = frame_data['hotspot_y']
        # print(f"  Frame Hotspot ({frame_hotspot_x}, {frame_hotspot_y}) corresponds to canvas coordinates: ({offset_x}, {offset_y})")

        return True
    except Exception as e:
        print(f"  Error saving final image {output_filename}: {e}")
        return False

# %% [markdown]
# ## Call Functions

# %%
# This calls all the necessary functions to parse the file, create the frames, sprites, and PNGs

# Populates parser object ...
parser = analyze_sprites_file('../src/graphics/sprites.anim')

# Export sprites to PNG files
export_sprites_to_png(parser)

# Define paths and naming template
sprite_base_path = "frames_output"  # Base path where individual sprite PNGs are located
sprite_file_template = "frame_{frame_idx}/sprite_{index}.png"
output_filename_template = "frames_output/frame_{frame_idx}/frame_{frame_idx}_combined.png"

# Iterate through frames and create combined images
for frame_idx, frame in enumerate(parser.frames):
    # Prepare frame data for create_frame_image
    frame_data = {
        "frame_index": frame_idx,
        "hotspot_x": frame.x_hot,
        "hotspot_y": frame.y_hot,
        "sprites": [
            {
                "index": sprite_idx,
                "size_tiles": (sprite.width, sprite.height),
                "pos_x": sprite.x_pos,
                "pos_y": sprite.y_pos
            }
            for sprite_idx, sprite in enumerate(frame.sprites)
        ]
    }

    # Format the output filename
    output_filename = output_filename_template.format(frame_idx=frame_idx)    

    # Call create_frame_image
    create_frame_image(
        frame_data,
        sprite_base_path,
        sprite_file_template.format(frame_idx=frame_idx, index="{index}"),  # Pass formatted template
        output_filename
    )
# Out:
# First 128 bytes of sprites.anim:
# Offset | Hex Values | ASCII
# --------------------------------------------------
# 000000 | 41 41 02 24 00 02 53 53 00 CD 00 C2 00 20 00 40  | AA.$..SS..... .@
# 000010 | 00 00 00 00 00 00 00 FF 00 00 00 00 00 FF FF FC  | ................
# 000020 | FF EC 00 00 00 00 00 00 00 FF 00 00 FF E7 07 00  | ................
# 000030 | 46 A0 FF F9 53 53 00 CD 00 C2 00 30 00 40 00 00  | F...SS.....0.@..
# 000040 | 00 00 00 00 00 FF 00 00 00 00 00 FF FF FF FF E8  | ................
# 000050 | 00 00 00 00 00 00 00 FF 00 01 FF E5 07 00 46 98  | ..............F.
# 000060 | FF F9 FF FD 20 00 46 0D FF F1 53 53 00 CD 00 C3  | .... .F...SS....
# 000070 | 00 20 00 40 00 00 00 00 00 00 00 FF 00 00 00 00  | . .@............
#
# ==================================================
#
# Analysis of: sprites.anim
# ==================================================
# Total number of frames: 549
# Tileset Data offset: 0x8928
# Palette Data offset: 0x9F34
#
# Frame 0:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -4
#   Y Hot: -20
#   Number of sprites: 1
#   Frame Hex Data: 535300CD00C20020004000000000000000FF0000000000FFFFFCFFEC00000000000000FF0000FFE7070046A0FFF9
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15D28
#     X Position: -7
#     Y Position: -25
#     Tile ID: 0x46A0
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE7070046A0FFF9
#
# ----------------------------------------
#
# Frame 1:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -1
#   Y Hot: -24
#   Number of sprites: 2
#   Frame Hex Data: 535300CD00C20030004000000000000000FF0000000000FFFFFFFFE800000000000000FF0001FFE507004698FFF9FFFD2000460DFFF1
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15C28
#     X Position: -7
#     Y Position: -27
#     Tile ID: 0x4698
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE507004698FFF9
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34AC8
#     X Position: -15
#     Y Position: -3
#     Tile ID: 0x460D
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFD2000460DFFF1
#
# ----------------------------------------
#
# Frame 2:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -2
#   Y Hot: -28
#   Number of sprites: 1
#   Frame Hex Data: 535300CD00C30020004000000000000000FF0000000000FFFFFEFFE400000000000000FF0000FFE107004690FFF8
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15B28
#     X Position: -8
#     Y Position: -31
#     Tile ID: 0x4690
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE107004690FFF8
#
# ----------------------------------------
#
# Frame 3:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -1
#   Y Hot: -25
#   Number of sprites: 1
#   Frame Hex Data: 535300CD00C20020004000000000000000FF0000000000FFFFFFFFE700000000000000FF0000FFE407004688FFFB
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15A28
#     X Position: -5
#     Y Position: -28
#     Tile ID: 0x4688
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE407004688FFFB
#
# ----------------------------------------
#
# Frame 4:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 1
#   Y Hot: -25
#   Number of sprites: 1
#   Frame Hex Data: 535300CD00C20020004000000000000000FF0000000000FF0001FFE700000000000000FF0000FFE307004680FFFB
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15928
#     X Position: -5
#     Y Position: -29
#     Tile ID: 0x4680
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE307004680FFFB
#
# ----------------------------------------
#
# Frame 5:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 16
#   Y Hot: -8
#   Number of sprites: 2
#   Frame Hex Data: 535300DB00C90040004000000000000000FF0000000000FF0010FFF800010000000000FF0001FFE807004678FFF9FFF62400434E0009
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15828
#     X Position: -7
#     Y Position: -24
#     Tile ID: 0x4678
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE807004678FFF9
#
#   Sprite 1:
#     Size: 2x1 tiles (16x8 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2F2E8
#     X Position: 9
#     Y Position: -10
#     Tile ID: 0x434E
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF62400434E0009
#
# ----------------------------------------
#
# Frame 6:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 23
#   Y Hot: -10
#   Number of sprites: 4
#   Frame Hex Data: 535300D800CD0040004000000000000000FF0000000000FF0017FFF600C80000000000FF0003FFF2190046DEFFFAFFF22000460C0012FFEA2400434CFFFCFFE22000460B0004
#
#   Sprite 0:
#     Size: 3x2 tiles (24x16 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x264E8
#     X Position: -6
#     Y Position: -14
#     Tile ID: 0x46DE
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF2190046DEFFFA
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34AA8
#     X Position: 18
#     Y Position: -14
#     Tile ID: 0x460C
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF22000460C0012
#
#   Sprite 2:
#     Size: 2x1 tiles (16x8 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2F2A8
#     X Position: -4
#     Y Position: -22
#     Tile ID: 0x434C
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEA2400434CFFFC
#
#   Sprite 3:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34A88
#     X Position: 4
#     Y Position: -30
#     Tile ID: 0x460B
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE22000460B0004
#
# ----------------------------------------
#
# Frame 7:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 19
#   Y Hot: -8
#   Number of sprites: 4
#   Frame Hex Data: 535300D900CC0030004C00000000000000FF0000000000FF0013FFF800C80000000000FF0003FFEA1600444AFFFCFFE22000460A0004FFF420004609000C0000200046080004
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x21268
#     X Position: -4
#     Y Position: -22
#     Tile ID: 0x444A
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEA1600444AFFFC
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34A68
#     X Position: 4
#     Y Position: -30
#     Tile ID: 0x460A
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE22000460A0004
#
#   Sprite 2:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34A48
#     X Position: 12
#     Y Position: -12
#     Tile ID: 0x4609
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF420004609000C
#
#   Sprite 3:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34A28
#     X Position: 4
#     Y Position: 0
#     Tile ID: 0x4608
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 0000200046080004
#
# ----------------------------------------
#
# Frame 8:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 21
#   Y Hot: -11
#   Number of sprites: 3
#   Frame Hex Data: 535300DA00CC0040004000000000000000FF0000000000FF0015FFF500C80000000000FF0002FFE607004670FFFBFFF520004607000BFFF1200046060013
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15728
#     X Position: -5
#     Y Position: -26
#     Tile ID: 0x4670
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE607004670FFFB
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34A08
#     X Position: 11
#     Y Position: -11
#     Tile ID: 0x4607
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF520004607000B
#
#   Sprite 2:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x349E8
#     X Position: 19
#     Y Position: -15
#     Tile ID: 0x4606
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF1200046060013
#
# ----------------------------------------
#
# Frame 9:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 14
#   Y Hot: -4
#   Number of sprites: 3
#   Frame Hex Data: 535300DB00CA0030004000000000000000FF0000000000FF000EFFFC00C80000000000FF0002FFE916004444FFFE000120004605FFFEFFF720004604000E
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x211A8
#     X Position: -2
#     Y Position: -23
#     Tile ID: 0x4444
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE916004444FFFE
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x349C8
#     X Position: -2
#     Y Position: 1
#     Tile ID: 0x4605
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 000120004605FFFE
#
#   Sprite 2:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x349A8
#     X Position: 14
#     Y Position: -9
#     Tile ID: 0x4604
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF720004604000E
#
# ----------------------------------------
#
# Frame 10:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 17
#   Y Hot: 3
#   Number of sprites: 2
#   Frame Hex Data: 535300EE00D80030004000000000000000FF0000000000FF0011000300C80000000000FF0001FFE807004668FFFD000020004603000D
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15628
#     X Position: -3
#     Y Position: -24
#     Tile ID: 0x4668
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE807004668FFFD
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34988
#     X Position: 13
#     Y Position: 0
#     Tile ID: 0x4603
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 000020004603000D
#
# ----------------------------------------
#
# Frame 11:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 21
#   Y Hot: 3
#   Number of sprites: 3
#   Frame Hex Data: 535300ED00D80040004000000000000000FF0000000000FF0015000300C80000000000FF0002FFE907004660FFFFFFF920004602FFF7FFFD20004601000F
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15528
#     X Position: -1
#     Y Position: -23
#     Tile ID: 0x4660
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE907004660FFFF
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34968
#     X Position: -9
#     Y Position: -7
#     Tile ID: 0x4602
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF920004602FFF7
#
#   Sprite 2:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34948
#     X Position: 15
#     Y Position: -3
#     Tile ID: 0x4601
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFD20004601000F
#
# ----------------------------------------
#
# Frame 12:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 21
#   Y Hot: 2
#   Number of sprites: 4
#   Frame Hex Data: 535300EF00D80040004000000000000000FF0000000000FF0015000200C80000000000FF0003FFE81600443EFFFF00002400434AFFFFFFFA20004600000FFFFB200045FFFFF7
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x210E8
#     X Position: -1
#     Y Position: -24
#     Tile ID: 0x443E
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE81600443EFFFF
#
#   Sprite 1:
#     Size: 2x1 tiles (16x8 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2F268
#     X Position: -1
#     Y Position: 0
#     Tile ID: 0x434A
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 00002400434AFFFF
#
#   Sprite 2:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34928
#     X Position: 15
#     Y Position: -6
#     Tile ID: 0x4600
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFA20004600000F
#
#   Sprite 3:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34908
#     X Position: -9
#     Y Position: -5
#     Tile ID: 0x45FF
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFB200045FFFFF7
#
# ----------------------------------------
#
# Frame 13:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 21
#   Y Hot: 3
#   Number of sprites: 4
#   Frame Hex Data: 535300F100D80050004000000000000000FF0000000000FF0015000300C80000000000FF0003FFEC16004438FFFCFFE4200045FE0004FFFC24004348000CFFF421004146FFF4
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x21028
#     X Position: -4
#     Y Position: -20
#     Tile ID: 0x4438
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEC16004438FFFC
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x348E8
#     X Position: 4
#     Y Position: -28
#     Tile ID: 0x45FE
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE4200045FE0004
#
#   Sprite 2:
#     Size: 2x1 tiles (16x8 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2F228
#     X Position: 12
#     Y Position: -4
#     Tile ID: 0x4348
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFC24004348000C
#
#   Sprite 3:
#     Size: 1x2 tiles (8x16 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2B1E8
#     X Position: -12
#     Y Position: -12
#     Tile ID: 0x4146
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF421004146FFF4
#
# ----------------------------------------
#
# Frame 14:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 18
#   Y Hot: 3
#   Number of sprites: 3
#   Frame Hex Data: 535300F300D80040004000000000000000FF0000000000FF0012000300C80000000000FF0002FFEC150047F0FFF9FFE4200045FD0001FFFC2C00417CFFF7
#
#   Sprite 0:
#     Size: 2x2 tiles (16x16 pixels)
#     Number of tiles: 4
#     Starting tile offset: 0x28728
#     X Position: -7
#     Y Position: -20
#     Tile ID: 0x47F0
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEC150047F0FFF9
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x348C8
#     X Position: 1
#     Y Position: -28
#     Tile ID: 0x45FD
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE4200045FD0001
#
#   Sprite 2:
#     Size: 4x1 tiles (32x8 pixels)
#     Number of tiles: 4
#     Starting tile offset: 0x2B8A8
#     X Position: -9
#     Y Position: -4
#     Tile ID: 0x417C
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFC2C00417CFFF7
#
# ----------------------------------------
#
# Frame 15:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 14
#   Y Hot: 6
#   Number of sprites: 2
#   Frame Hex Data: 535300E500F10040004000000000000000FF0000000000FF000E000600C80000000000FF0001FFE807004658FFF80000240043460008
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15428
#     X Position: -8
#     Y Position: -24
#     Tile ID: 0x4658
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE807004658FFF8
#
#   Sprite 1:
#     Size: 2x1 tiles (16x8 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2F1E8
#     X Position: 8
#     Y Position: 0
#     Tile ID: 0x4346
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 0000240043460008
#
# ----------------------------------------
#
# Frame 16:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 17
#   Y Hot: 14
#   Number of sprites: 2
#   Frame Hex Data: 535300E200EC0030004000000000000000FF0000000000FF0011000E00C80000000000FF0001FFEF07004650FFFE0007200045FC000E
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15328
#     X Position: -2
#     Y Position: -17
#     Tile ID: 0x4650
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEF07004650FFFE
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x348A8
#     X Position: 14
#     Y Position: 7
#     Tile ID: 0x45FC
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 0007200045FC000E
#
# ----------------------------------------
#
# Frame 17:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 17
#   Y Hot: 10
#   Number of sprites: 2
#   Frame Hex Data: 535300E500F00040004400000000000000FF0000000000FF0011000A00C80000000000FF0001FFEA07004648FFFA000424004346000A
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15228
#     X Position: -6
#     Y Position: -22
#     Tile ID: 0x4648
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEA07004648FFFA
#
#   Sprite 1:
#     Size: 2x1 tiles (16x8 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2F1E8
#     X Position: 10
#     Y Position: 4
#     Tile ID: 0x4346
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 000424004346000A
#
# ----------------------------------------
#
# Frame 18:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 19
#   Y Hot: 11
#   Number of sprites: 5
#   Frame Hex Data: 535300E600F00050005000000000000000FF0000000000FF0013000B00C80000000000FF0004FFEE16004432FFFAFFE6200045FB0002FFFE21004144000A0006200045FA0012FFFD200045F9FFF2
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x20F68
#     X Position: -6
#     Y Position: -18
#     Tile ID: 0x4432
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEE16004432FFFA
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34888
#     X Position: 2
#     Y Position: -26
#     Tile ID: 0x45FB
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE6200045FB0002
#
#   Sprite 2:
#     Size: 1x2 tiles (8x16 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2B1A8
#     X Position: 10
#     Y Position: -2
#     Tile ID: 0x4144
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFE21004144000A
#
#   Sprite 3:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34868
#     X Position: 18
#     Y Position: 6
#     Tile ID: 0x45FA
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 0006200045FA0012
#
#   Sprite 4:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34848
#     X Position: -14
#     Y Position: -3
#     Tile ID: 0x45F9
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFD200045F9FFF2
#
# ----------------------------------------
#
# Frame 19:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 17
#   Y Hot: 10
#   Number of sprites: 4
#   Frame Hex Data: 535300E600F10042004C00000000000000FF0000000000FF0011000A00C80000000000FF0003FFEE1600442CFFFBFFE6200045F80003FFFE200045F7FFF30004240043440004
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x20EA8
#     X Position: -5
#     Y Position: -18
#     Tile ID: 0x442C
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEE1600442CFFFB
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34828
#     X Position: 3
#     Y Position: -26
#     Tile ID: 0x45F8
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE6200045F80003
#
#   Sprite 2:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34808
#     X Position: -13
#     Y Position: -2
#     Tile ID: 0x45F7
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFE200045F7FFF3
#
#   Sprite 3:
#     Size: 2x1 tiles (16x8 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2F1A8
#     X Position: 4
#     Y Position: 4
#     Tile ID: 0x4344
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 0004240043440004
#
# ----------------------------------------
#
# Frame 20:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 2
#   Y Hot: 16
#   Number of sprites: 2
#   Frame Hex Data: 535300CC01050020005000000000000000FF0000000000FF0002001000C80000000000FF0001FFEB07004640FFF8000B200045F60000
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15128
#     X Position: -8
#     Y Position: -21
#     Tile ID: 0x4640
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEB07004640FFF8
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x347E8
#     X Position: 0
#     Y Position: 11
#     Tile ID: 0x45F6
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 000B200045F60000
#
# ----------------------------------------
#
# Frame 21:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 1
#   Y Hot: 20
#   Number of sprites: 4
#   Frame Hex Data: 535300CC01050030006000000000000000FF0000000000FF0001001400C80000000000FF0003FFED16004426FFF8FFFC200045F50008000521004142FFFA0015200045F4FFFA
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x20DE8
#     X Position: -8
#     Y Position: -19
#     Tile ID: 0x4426
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFED16004426FFF8
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x347C8
#     X Position: 8
#     Y Position: -4
#     Tile ID: 0x45F5
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFC200045F50008
#
#   Sprite 2:
#     Size: 1x2 tiles (8x16 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2B168
#     X Position: -6
#     Y Position: 5
#     Tile ID: 0x4142
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 000521004142FFFA
#
#   Sprite 3:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x347A8
#     X Position: -6
#     Y Position: 21
#     Tile ID: 0x45F4
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 0015200045F4FFFA
#
# ----------------------------------------
#
# Frame 22:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 4
#   Y Hot: 15
#   Number of sprites: 2
#   Frame Hex Data: 535300CC01080020005000000000000000FF0000000000FF0004000F00C80000000000FF0001FFEA07004638FFF8000A200045F30000
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x15028
#     X Position: -8
#     Y Position: -22
#     Tile ID: 0x4638
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEA07004638FFF8
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34788
#     X Position: 0
#     Y Position: 10
#     Tile ID: 0x45F3
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 000A200045F30000
#
# ----------------------------------------
#
# Frame 23:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 4
#   Y Hot: 20
#   Number of sprites: 2
#   Frame Hex Data: 535300CD01060020006000000000000000FF0000000000FF0004001400C80000000000FF0001FFED07004630FFF8000D210041400000
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x14F28
#     X Position: -8
#     Y Position: -19
#     Tile ID: 0x4630
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFED07004630FFF8
#
#   Sprite 1:
#     Size: 1x2 tiles (8x16 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2B128
#     X Position: 0
#     Y Position: 13
#     Tile ID: 0x4140
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 000D210041400000
#
# ----------------------------------------
#
# Frame 24:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 0
#   Y Hot: 20
#   Number of sprites: 2
#   Frame Hex Data: 535300CD01030020005000000000000000FF0000000000FF0000001400C80000000000FF0001FFF216004420FFFA000A2100413EFFFA
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x20D28
#     X Position: -6
#     Y Position: -14
#     Tile ID: 0x4420
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF216004420FFFA
#
#   Sprite 1:
#     Size: 1x2 tiles (8x16 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2B0E8
#     X Position: -6
#     Y Position: 10
#     Tile ID: 0x413E
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 000A2100413EFFFA
#
# ----------------------------------------
#
# Frame 25:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -8
#   Y Hot: 6
#   Number of sprites: 2
#   Frame Hex Data: 535300A700FE0030004000000000000000FF0000000000FFFFF8000600C80000000000FF0001FFE907004628FFFB0001200045F2FFF3
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x14E28
#     X Position: -5
#     Y Position: -23
#     Tile ID: 0x4628
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE907004628FFFB
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34768
#     X Position: -13
#     Y Position: 1
#     Tile ID: 0x45F2
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 0001200045F2FFF3
#
# ----------------------------------------
#
# Frame 26:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -13
#   Y Hot: 11
#   Number of sprites: 3
#   Frame Hex Data: 535300A700FD0040004000000000000000FF0000000000FFFFF3000B00C80000000000FF0002FFED1600441AFFF7FFFD200045F10007FFFD2100413CFFEF
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x20C68
#     X Position: -9
#     Y Position: -19
#     Tile ID: 0x441A
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFED1600441AFFF7
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34748
#     X Position: 7
#     Y Position: -3
#     Tile ID: 0x45F1
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFD200045F10007
#
#   Sprite 2:
#     Size: 1x2 tiles (8x16 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2B0A8
#     X Position: -17
#     Y Position: -3
#     Tile ID: 0x413C
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFD2100413CFFEF
#
# ----------------------------------------
#
# Frame 27:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -14
#   Y Hot: 12
#   Number of sprites: 2
#   Frame Hex Data: 535300AA00FD002E004000000000000000FF0000000000FFFFF2000C00C80000000000FF0001FFEE16004414FFF50006200045F0FFEE
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x20BA8
#     X Position: -11
#     Y Position: -18
#     Tile ID: 0x4414
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEE16004414FFF5
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34728
#     X Position: -18
#     Y Position: 6
#     Tile ID: 0x45F0
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 0006200045F0FFEE
#
# ----------------------------------------
#
# Frame 28:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -17
#   Y Hot: 14
#   Number of sprites: 4
#   Frame Hex Data: 535300AA00FB0032005000000000000000FF0000000000FFFFEF000E00C80000000000FF0003FFF31600440EFFF50003200045EFFFEDFFEB200045EEFFF5000B200045EDFFEC
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x20AE8
#     X Position: -11
#     Y Position: -13
#     Tile ID: 0x440E
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF31600440EFFF5
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34708
#     X Position: -19
#     Y Position: 3
#     Tile ID: 0x45EF
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 0003200045EFFFED
#
#   Sprite 2:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x346E8
#     X Position: -11
#     Y Position: -21
#     Tile ID: 0x45EE
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEB200045EEFFF5
#
#   Sprite 3:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x346C8
#     X Position: -20
#     Y Position: 11
#     Tile ID: 0x45ED
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 000B200045EDFFEC
#
# ----------------------------------------
#
# Frame 29:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -15
#   Y Hot: 12
#   Number of sprites: 3
#   Frame Hex Data: 535300A900FD0030004A00000000000000FF0000000000FFFFF1000C00C80000000000FF0002FFF216004408FFF5FFEA200045EEFFF50007200045ECFFED
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x20A28
#     X Position: -11
#     Y Position: -14
#     Tile ID: 0x4408
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF216004408FFF5
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x346E8
#     X Position: -11
#     Y Position: -22
#     Tile ID: 0x45EE
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEA200045EEFFF5
#
#   Sprite 2:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x346A8
#     X Position: -19
#     Y Position: 7
#     Tile ID: 0x45EC
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 0007200045ECFFED
#
# ----------------------------------------
#
# Frame 30:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -13
#   Y Hot: 3
#   Number of sprites: 2
#   Frame Hex Data: 535300A600D70030004000000000000000FF0000000000FFFFF3000300C80000000000FF0001FFE907004620FFF7FFFE200045EBFFEF
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x14D28
#     X Position: -9
#     Y Position: -23
#     Tile ID: 0x4620
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE907004620FFF7
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34688
#     X Position: -17
#     Y Position: -2
#     Tile ID: 0x45EB
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFE200045EBFFEF
#
# ----------------------------------------
#
# Frame 31:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -20
#   Y Hot: 1
#   Number of sprites: 4
#   Frame Hex Data: 535300A700D80050005200000000000000FF0000000000FFFFEC000100C80000000000FF0003FFEA16004402FFF3FFE2200045EAFFF3FFFB2100413A0003FFFB24004342FFE3
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x20968
#     X Position: -13
#     Y Position: -22
#     Tile ID: 0x4402
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEA16004402FFF3
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34668
#     X Position: -13
#     Y Position: -30
#     Tile ID: 0x45EA
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE2200045EAFFF3
#
#   Sprite 2:
#     Size: 1x2 tiles (8x16 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2B068
#     X Position: 3
#     Y Position: -5
#     Tile ID: 0x413A
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFB2100413A0003
#
#   Sprite 3:
#     Size: 2x1 tiles (16x8 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2F168
#     X Position: -29
#     Y Position: -5
#     Tile ID: 0x4342
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFB24004342FFE3
#
# ----------------------------------------
#
# Frame 32:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -14
#   Y Hot: 3
#   Number of sprites: 2
#   Frame Hex Data: 535300A400D70030004000000000000000FF0000000000FFFFF2000300C80000000000FF0001FFE907004618FFF7FFFD200045E9FFEF
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x14C28
#     X Position: -9
#     Y Position: -23
#     Tile ID: 0x4618
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE907004618FFF7
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34648
#     X Position: -17
#     Y Position: -3
#     Tile ID: 0x45E9
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFD200045E9FFEF
#
# ----------------------------------------
#
# Frame 33:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -15
#   Y Hot: 2
#   Number of sprites: 5
#   Frame Hex Data: 535300A300D90050004000000000000000FF0000000000FFFFF1000200C80000000000FF0004FFED160043FCFFF9FFE5200045E8FFF9FFFB200045E70009FFFB200045E6FFE9FFFA200045E5FFF1
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x208A8
#     X Position: -7
#     Y Position: -19
#     Tile ID: 0x43FC
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFED160043FCFFF9
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34628
#     X Position: -7
#     Y Position: -27
#     Tile ID: 0x45E8
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE5200045E8FFF9
#
#   Sprite 2:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34608
#     X Position: 9
#     Y Position: -5
#     Tile ID: 0x45E7
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFB200045E70009
#
#   Sprite 3:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x345E8
#     X Position: -23
#     Y Position: -5
#     Tile ID: 0x45E6
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFB200045E6FFE9
#
#   Sprite 4:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x345C8
#     X Position: -15
#     Y Position: -6
#     Tile ID: 0x45E5
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFA200045E5FFF1
#
# ----------------------------------------
#
# Frame 34:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -13
#   Y Hot: 3
#   Number of sprites: 2
#   Frame Hex Data: 535300A300D80030004000000000000000FF0000000000FFFFF3000300C80000000000FF0001FFE807004610FFF8FFFD200045E4FFF0
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x14B28
#     X Position: -8
#     Y Position: -24
#     Tile ID: 0x4610
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE807004610FFF8
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x345A8
#     X Position: -16
#     Y Position: -3
#     Tile ID: 0x45E4
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFD200045E4FFF0
#
# ----------------------------------------
#
# Frame 35:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -14
#   Y Hot: -8
#   Number of sprites: 2
#   Frame Hex Data: 535300B500C00030004000000000000000FF0000000000FFFFF2FFF800C80000000000FF0001FFE607004608FFF7FFF6200045E3FFEF
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x14A28
#     X Position: -9
#     Y Position: -26
#     Tile ID: 0x4608
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE607004608FFF7
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34588
#     X Position: -17
#     Y Position: -10
#     Tile ID: 0x45E3
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF6200045E3FFEF
#
# ----------------------------------------
#
# Frame 36:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -15
#   Y Hot: -7
#   Number of sprites: 2
#   Frame Hex Data: 535300B500C00030004000000000000000FF0000000000FFFFF1FFF900C80000000000FF0001FFE507004600FFF6FFF5200045E2FFEE
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x14928
#     X Position: -10
#     Y Position: -27
#     Tile ID: 0x4600
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE507004600FFF6
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34568
#     X Position: -18
#     Y Position: -11
#     Tile ID: 0x45E2
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF5200045E2FFEE
#
# ----------------------------------------
#
# Frame 37:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -14
#   Y Hot: -7
#   Number of sprites: 3
#   Frame Hex Data: 535300B500BF0040004000000000000000FF0000000000FFFFF2FFF900C80000000000FF0002FFEC160043F6FFF7FFE4200045E1FFF7FFF624004340FFE7
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x207E8
#     X Position: -9
#     Y Position: -20
#     Tile ID: 0x43F6
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEC160043F6FFF7
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34548
#     X Position: -9
#     Y Position: -28
#     Tile ID: 0x45E1
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE4200045E1FFF7
#
#   Sprite 2:
#     Size: 2x1 tiles (16x8 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2F128
#     X Position: -25
#     Y Position: -10
#     Tile ID: 0x4340
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF624004340FFE7
#
# ----------------------------------------
#
# Frame 38:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -15
#   Y Hot: -8
#   Number of sprites: 4
#   Frame Hex Data: 535300B400C00050004000000000000000FF0000000000FFFFF1FFF800C80000000000FF0003FFEB160043F0FFF9FFFA200045E00009FFE3200045DFFFF9FFF52400433EFFE9
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x20728
#     X Position: -7
#     Y Position: -21
#     Tile ID: 0x43F0
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEB160043F0FFF9
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34528
#     X Position: 9
#     Y Position: -6
#     Tile ID: 0x45E0
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFA200045E00009
#
#   Sprite 2:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34508
#     X Position: -7
#     Y Position: -29
#     Tile ID: 0x45DF
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE3200045DFFFF9
#
#   Sprite 3:
#     Size: 2x1 tiles (16x8 pixels)
#     Number of tiles: 2
#     Starting tile offset: 0x2F0E8
#     X Position: -23
#     Y Position: -11
#     Tile ID: 0x433E
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF52400433EFFE9
#
# ----------------------------------------
#
# Frame 39:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: -13
#   Y Hot: -9
#   Number of sprites: 5
#   Frame Hex Data: 535300B300C00040005000000000000000FF0000000000FFFFF3FFF700C80000000000FF0004FFEB160043EAFFF8FFFB200045DE00080003200045DD0000FFF3200045DCFFF0FFE3200045DBFFFA
#
#   Sprite 0:
#     Size: 2x3 tiles (16x24 pixels)
#     Number of tiles: 6
#     Starting tile offset: 0x20668
#     X Position: -8
#     Y Position: -21
#     Tile ID: 0x43EA
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEB160043EAFFF8
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x344E8
#     X Position: 8
#     Y Position: -5
#     Tile ID: 0x45DE
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFB200045DE0008
#
#   Sprite 2:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x344C8
#     X Position: 0
#     Y Position: 3
#     Tile ID: 0x45DD
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: 0003200045DD0000
#
#   Sprite 3:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x344A8
#     X Position: -16
#     Y Position: -13
#     Tile ID: 0x45DC
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF3200045DCFFF0
#
#   Sprite 4:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34488
#     X Position: -6
#     Y Position: -29
#     Tile ID: 0x45DB
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE3200045DBFFFA
#
# ----------------------------------------
#
# Frame 40:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 1
#   Y Hot: -13
#   Number of sprites: 2
#   Frame Hex Data: 535300CD00BD002C004000000000000000FF0000000000FF0001FFF300C80000000000FF0001FFE5070045F8FFF7FFED200045DAFFF1
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x14828
#     X Position: -9
#     Y Position: -27
#     Tile ID: 0x45F8
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE5070045F8FFF7
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34468
#     X Position: -15
#     Y Position: -19
#     Tile ID: 0x45DA
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFED200045DAFFF1
#
# ----------------------------------------
#
# Frame 41:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 1
#   Y Hot: -11
#   Number of sprites: 3
#   Frame Hex Data: 535300CD00BB0030004000000000000000FF0000000000FF0001FFF500C80000000000FF0002FFE7070045F0FFF9FFFF200045D9FFF1FFEF200045D8FFF1
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x14728
#     X Position: -7
#     Y Position: -25
#     Tile ID: 0x45F0
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE7070045F0FFF9
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34448
#     X Position: -15
#     Y Position: -1
#     Tile ID: 0x45D9
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFFF200045D9FFF1
#
#   Sprite 2:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34428
#     X Position: -15
#     Y Position: -17
#     Tile ID: 0x45D8
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFEF200045D8FFF1
#
# ----------------------------------------
#
# Frame 42:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 1
#   Y Hot: -12
#   Number of sprites: 2
#   Frame Hex Data: 535300CD00BC0030004000000000000000FF0000000000FF0001FFF400C80000000000FF0001FFE6070045E8FFF9FFF2200045D7FFF1
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x14628
#     X Position: -7
#     Y Position: -26
#     Tile ID: 0x45E8
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE6070045E8FFF9
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x34408
#     X Position: -15
#     Y Position: -14
#     Tile ID: 0x45D7
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFF2200045D7FFF1
#
# ----------------------------------------
#
# Frame 43:
#   SprStrAtt: 0x0000
#   SprStrHot: 0x0000
#   X Hot: 0
#   Y Hot: -12
#   Number of sprites: 2
#   Frame Hex Data: 535300CC00BC0030004000000000000000FF0000000000FF0000FFF400C80000000000FF0001FFE6070045E0FFF7FFEE200045D6FFEF
#
#   Sprite 0:
#     Size: 2x4 tiles (16x32 pixels)
#     Number of tiles: 8
#     Starting tile offset: 0x14528
#     X Position: -9
#     Y Position: -26
#     Tile ID: 0x45E0
#     Palette ID: 2
#     Priority: 0
#     Vertical Flip (vflip): 0
#     Horizontal Flip (hflip): 0
#     Sprite Hex Data: FFE6070045E0FFF7
#
#   Sprite 1:
#     Size: 1x1 tiles (8x8 pixels)
#     Number of tiles: 1
#     Starting tile offset: 0x343E8
# ...
#   Successfully combined sprites into frames_output/frame_479/frame_479_combined.png
#
# --- Processing Frame 480 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-9, 15], Y=[-26, 9]
#   Calculated Canvas Size: 24 x 35
#   Placement Offset (Hotspot's pos on canvas): (9, 26)
#   Pasting 3 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_480/frame_480_combined.png
#
# --- Processing Frame 481 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-13, 11], Y=[-28, 12]
#   Calculated Canvas Size: 24 x 40
#   Placement Offset (Hotspot's pos on canvas): (13, 28)
#   Pasting 3 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_481/frame_481_combined.png
#
# --- Processing Frame 482 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-8, 16], Y=[-31, 9]
#   Calculated Canvas Size: 24 x 40
#   Placement Offset (Hotspot's pos on canvas): (8, 31)
#   Pasting 3 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_482/frame_482_combined.png
#
# --- Processing Frame 483 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-12, 19], Y=[-27, 13]
#   Calculated Canvas Size: 31 x 40
#   Placement Offset (Hotspot's pos on canvas): (12, 27)
#   Pasting 5 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_483/frame_483_combined.png
#
# --- Processing Frame 484 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-6, 18], Y=[-26, 6]
#   Calculated Canvas Size: 24 x 32
#   Placement Offset (Hotspot's pos on canvas): (6, 26)
#   Pasting 3 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_484/frame_484_combined.png
#
# --- Processing Frame 485 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-11, 21], Y=[-28, 4]
#   Calculated Canvas Size: 32 x 32
#   Placement Offset (Hotspot's pos on canvas): (11, 28)
#   Pasting 3 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_485/frame_485_combined.png
#
# --- Processing Frame 486 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-14, 18], Y=[-28, 4]
#   Calculated Canvas Size: 32 x 32
#   Placement Offset (Hotspot's pos on canvas): (14, 28)
#   Pasting 5 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_486/frame_486_combined.png
#
# --- Processing Frame 487 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-9, 16], Y=[-26, 6]
#   Calculated Canvas Size: 25 x 32
#   Placement Offset (Hotspot's pos on canvas): (9, 26)
#   Pasting 4 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_487/frame_487_combined.png
#
# --- Processing Frame 488 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-14, 18], Y=[-25, 7]
#   Calculated Canvas Size: 32 x 32
#   Placement Offset (Hotspot's pos on canvas): (14, 25)
#   Pasting 5 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_488/frame_488_combined.png
#
# --- Processing Frame 489 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-15, 25], Y=[-28, 12]
#   Calculated Canvas Size: 40 x 40
#   Placement Offset (Hotspot's pos on canvas): (15, 28)
#   Pasting 6 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_489/frame_489_combined.png
#
# --- Processing Frame 490 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-10, 22], Y=[-27, 5]
#   Calculated Canvas Size: 32 x 32
#   Placement Offset (Hotspot's pos on canvas): (10, 27)
#   Pasting 4 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_490/frame_490_combined.png
#
# --- Processing Frame 491 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-13, 11], Y=[-26, 6]
#   Calculated Canvas Size: 24 x 32
#   Placement Offset (Hotspot's pos on canvas): (13, 26)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_491/frame_491_combined.png
#
# --- Processing Frame 492 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-16, 16], Y=[-31, 9]
#   Calculated Canvas Size: 32 x 40
#   Placement Offset (Hotspot's pos on canvas): (16, 31)
#   Pasting 5 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_492/frame_492_combined.png
#
# --- Processing Frame 493 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-15, 17], Y=[-29, 11]
#   Calculated Canvas Size: 32 x 40
#   Placement Offset (Hotspot's pos on canvas): (15, 29)
#   Pasting 5 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_493/frame_493_combined.png
#
# --- Processing Frame 494 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-12, 20], Y=[-23, 17]
#   Calculated Canvas Size: 32 x 40
#   Placement Offset (Hotspot's pos on canvas): (12, 23)
#   Pasting 4 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_494/frame_494_combined.png
#
# --- Processing Frame 495 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-13, 11], Y=[-19, 13]
#   Calculated Canvas Size: 24 x 32
#   Placement Offset (Hotspot's pos on canvas): (13, 19)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_495/frame_495_combined.png
#
# --- Processing Frame 496 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-14, 10], Y=[-23, 17]
#   Calculated Canvas Size: 24 x 40
#   Placement Offset (Hotspot's pos on canvas): (14, 23)
#   Pasting 3 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_496/frame_496_combined.png
#
# --- Processing Frame 497 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-14, 10], Y=[-20, 20]
#   Calculated Canvas Size: 24 x 40
#   Placement Offset (Hotspot's pos on canvas): (14, 20)
#   Pasting 3 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_497/frame_497_combined.png
#
# --- Processing Frame 498 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-18, 6], Y=[-27, 13]
#   Calculated Canvas Size: 24 x 40
#   Placement Offset (Hotspot's pos on canvas): (18, 27)
#   Pasting 4 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_498/frame_498_combined.png
#
# --- Processing Frame 499 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-16, 13], Y=[-26, 10]
#   Calculated Canvas Size: 29 x 36
#   Placement Offset (Hotspot's pos on canvas): (16, 26)
#   Pasting 4 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_499/frame_499_combined.png
#
# --- Processing Frame 500 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-18, 6], Y=[-26, 7]
#   Calculated Canvas Size: 24 x 33
#   Placement Offset (Hotspot's pos on canvas): (18, 26)
#   Pasting 3 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_500/frame_500_combined.png
#
# --- Processing Frame 501 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-22, 18], Y=[-23, 9]
#   Calculated Canvas Size: 40 x 32
#   Placement Offset (Hotspot's pos on canvas): (22, 23)
#   Pasting 4 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_501/frame_501_combined.png
#
# --- Processing Frame 502 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-19, 13], Y=[-25, 15]
#   Calculated Canvas Size: 32 x 40
#   Placement Offset (Hotspot's pos on canvas): (19, 25)
#   Pasting 5 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_502/frame_502_combined.png
#
# --- Processing Frame 503 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-23, 9], Y=[-24, 11]
#   Calculated Canvas Size: 32 x 35
#   Placement Offset (Hotspot's pos on canvas): (23, 24)
#   Pasting 4 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_503/frame_503_combined.png
#
# --- Processing Frame 504 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-17, 7], Y=[-24, 8]
#   Calculated Canvas Size: 24 x 32
#   Placement Offset (Hotspot's pos on canvas): (17, 24)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_504/frame_504_combined.png
#
# --- Processing Frame 505 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-21, 11], Y=[-24, 8]
#   Calculated Canvas Size: 32 x 32
#   Placement Offset (Hotspot's pos on canvas): (21, 24)
#   Pasting 3 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_505/frame_505_combined.png
#
# --- Processing Frame 506 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-22, 10], Y=[-24, 8]
#   Calculated Canvas Size: 32 x 32
#   Placement Offset (Hotspot's pos on canvas): (22, 24)
#   Pasting 3 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_506/frame_506_combined.png
#
# --- Processing Frame 507 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-22, 10], Y=[-26, 6]
#   Calculated Canvas Size: 32 x 32
#   Placement Offset (Hotspot's pos on canvas): (22, 26)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_507/frame_507_combined.png
#
# --- Processing Frame 508 ---
#   Only one sprite defined for frame 508. Skipping.
#
# --- Processing Frame 509 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-20, 12], Y=[-28, 5]
#   Calculated Canvas Size: 32 x 33
#   Placement Offset (Hotspot's pos on canvas): (20, 28)
#   Pasting 4 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_509/frame_509_combined.png
#
# --- Processing Frame 510 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-16, 8], Y=[-27, 5]
#   Calculated Canvas Size: 24 x 32
#   Placement Offset (Hotspot's pos on canvas): (16, 27)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_510/frame_510_combined.png
#
# --- Processing Frame 511 ---
#   Only one sprite defined for frame 511. Skipping.
#
# --- Processing Frame 512 ---
#   Only one sprite defined for frame 512. Skipping.
#
# --- Processing Frame 513 ---
#   Only one sprite defined for frame 513. Skipping.
#
# --- Processing Frame 514 ---
#   Only one sprite defined for frame 514. Skipping.
#
# --- Processing Frame 515 ---
#   Only one sprite defined for frame 515. Skipping.
#
# --- Processing Frame 516 ---
#   Only one sprite defined for frame 516. Skipping.
#
# --- Processing Frame 517 ---
#   Only one sprite defined for frame 517. Skipping.
#
# --- Processing Frame 518 ---
#   Only one sprite defined for frame 518. Skipping.
#
# --- Processing Frame 519 ---
#   Only one sprite defined for frame 519. Skipping.
#
# --- Processing Frame 520 ---
#   Only one sprite defined for frame 520. Skipping.
#
# --- Processing Frame 521 ---
#   Only one sprite defined for frame 521. Skipping.
#
# --- Processing Frame 522 ---
#   Only one sprite defined for frame 522. Skipping.
#
# --- Processing Frame 523 ---
#   Only one sprite defined for frame 523. Skipping.
#
# --- Processing Frame 524 ---
#   Only one sprite defined for frame 524. Skipping.
#
# --- Processing Frame 525 ---
#   Only one sprite defined for frame 525. Skipping.
#
# --- Processing Frame 526 ---
#   Only one sprite defined for frame 526. Skipping.
#
# --- Processing Frame 527 ---
#   Only one sprite defined for frame 527. Skipping.
#
# --- Processing Frame 528 ---
#   Only one sprite defined for frame 528. Skipping.
#
# --- Processing Frame 529 ---
#   Only one sprite defined for frame 529. Skipping.
#
# --- Processing Frame 530 ---
#   Only one sprite defined for frame 530. Skipping.
#
# --- Processing Frame 531 ---
#   Only one sprite defined for frame 531. Skipping.
#
# --- Processing Frame 532 ---
#   Only one sprite defined for frame 532. Skipping.
#
# --- Processing Frame 533 ---
#   Only one sprite defined for frame 533. Skipping.
#
# --- Processing Frame 534 ---
#   Only one sprite defined for frame 534. Skipping.
#
# --- Processing Frame 535 ---
#   Only one sprite defined for frame 535. Skipping.
#
# --- Processing Frame 536 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-11, 5], Y=[-5, 11]
#   Calculated Canvas Size: 16 x 16
#   Placement Offset (Hotspot's pos on canvas): (11, 5)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_536/frame_536_combined.png
#
# --- Processing Frame 537 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-8, 8], Y=[-6, 10]
#   Calculated Canvas Size: 16 x 16
#   Placement Offset (Hotspot's pos on canvas): (8, 6)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_537/frame_537_combined.png
#
# --- Processing Frame 538 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-17, 15], Y=[-11, 13]
#   Calculated Canvas Size: 32 x 24
#   Placement Offset (Hotspot's pos on canvas): (17, 11)
#   Pasting 4 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_538/frame_538_combined.png
#
# --- Processing Frame 539 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-9, 7], Y=[-6, 10]
#   Calculated Canvas Size: 16 x 16
#   Placement Offset (Hotspot's pos on canvas): (9, 6)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_539/frame_539_combined.png
#
# --- Processing Frame 540 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-5, 11], Y=[-5, 11]
#   Calculated Canvas Size: 16 x 16
#   Placement Offset (Hotspot's pos on canvas): (5, 5)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_540/frame_540_combined.png
#
# --- Processing Frame 541 ---
#   Only one sprite defined for frame 541. Skipping.
#
# --- Processing Frame 542 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-5, 26], Y=[-16, 4]
#   Calculated Canvas Size: 31 x 20
#   Placement Offset (Hotspot's pos on canvas): (5, 16)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_542/frame_542_combined.png
#
# --- Processing Frame 543 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-5, 12], Y=[-19, 4]
#   Calculated Canvas Size: 17 x 23
#   Placement Offset (Hotspot's pos on canvas): (5, 19)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_543/frame_543_combined.png
#
# --- Processing Frame 544 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-5, 11], Y=[-18, 4]
#   Calculated Canvas Size: 16 x 22
#   Placement Offset (Hotspot's pos on canvas): (5, 18)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_544/frame_544_combined.png
#
# --- Processing Frame 545 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-12, 4], Y=[-21, 4]
#   Calculated Canvas Size: 16 x 25
#   Placement Offset (Hotspot's pos on canvas): (12, 21)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_545/frame_545_combined.png
#
# --- Processing Frame 546 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-12, 4], Y=[-18, 4]
#   Calculated Canvas Size: 16 x 22
#   Placement Offset (Hotspot's pos on canvas): (12, 18)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_546/frame_546_combined.png
#
# --- Processing Frame 547 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-13, 4], Y=[-19, 4]
#   Calculated Canvas Size: 17 x 23
#   Placement Offset (Hotspot's pos on canvas): (13, 19)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_547/frame_547_combined.png
#
# --- Processing Frame 548 ---
#   Loading and analyzing sprites...
#   Overall Bounds Rel Hotspot: X=[-27, 4], Y=[-16, 4]
#   Calculated Canvas Size: 31 x 20
#   Placement Offset (Hotspot's pos on canvas): (27, 16)
#   Pasting 2 sprites onto canvas...
#   Successfully combined sprites into frames_output/frame_548/frame_548_combined.png

# %% [markdown]
# ## Create Animation from PNG

# %%
import os
import glob
from PIL import Image
import numpy as np
import imageio

def create_animation_gif(start_frame, end_frame, direction_num, output_filename, animation_data=None):
    """
    Create an animated GIF for a specific direction of animation frames
    
    Parameters:
    - start_frame: starting frame number
    - end_frame: ending frame number
    - direction_num: 0-7 for the direction
    - output_filename: name of output GIF file
    - animation_data: list of frame durations from frames.asm
    """
    # Calculate frame numbers for the specified direction
    frame_offset = direction_num * 5  # 5 frames per direction
    frame_numbers = [start_frame + frame_offset + i for i in range(5)]
    
    # Default frame durations if not provided (60fps game = ~16.7ms per frame)
    if animation_data is None:
        durations = [167] * len(frame_numbers)  # 167ms = ~6fps
    else:
        # Convert game frames to milliseconds (assuming 60fps)
        durations = [abs(frame_time) * 1000 / 60 for frame_time in animation_data]
    
    # Collect all combined frames
    frames = []
    max_width = 0
    max_height = 0
    
    # First pass to find the maximum dimensions
    temp_frames = []
    for frame_num in frame_numbers:
        frame_dir = f"frames_output/frame_{frame_num}"
        
        # Check if there's a combined image
        combined_path = f"{frame_dir}/frame_{frame_num}_combined.png"
        
        if os.path.exists(combined_path):
            # Use the pre-combined image
            img = Image.open(combined_path)
            width, height = img.size
            temp_frames.append(img)
        else:
            # Find all sprite PNGs for this frame
            sprite_paths = sorted(glob.glob(f"{frame_dir}/sprite_*.png"))
            
            if not sprite_paths:
                print(f"Warning: No sprites found for frame {frame_num}")
                continue
                
            # Open all sprites to calculate total dimensions
            sprites = [Image.open(path) for path in sprite_paths]
            
            # Create a transparent base image
            # For simplicity, just use dimensions of first sprite
            base_img = sprites[0]
            width, height = base_img.size
            
            # Create a new image with the sprites
            combined = Image.new("RGBA", (width, height), (0, 0, 0, 0))
            
            # Paste all sprites
            for sprite in sprites:
                combined.paste(sprite, (0, 0), sprite)
            
            temp_frames.append(combined)
            
        # Update maximum dimensions
        max_width = max(max_width, width)
        max_height = max(max_height, height)
    
    # Second pass to resize all frames to the same dimensions
    for img in temp_frames:
        # Create a new image with the maximum dimensions
        resized = Image.new("RGBA", (max_width, max_height), (0, 0, 0, 0))
        # Paste the original image centered
        offset_x = (max_width - img.width) // 2
        offset_y = (max_height - img.height) // 2
        resized.paste(img, (offset_x, offset_y), img)
        # Convert to RGB for GIF compatibility
        rgb_img = Image.new("RGB", resized.size, (0, 0, 0))
        rgb_img.paste(resized, (0, 0), resized)
        frames.append(np.array(rgb_img))
    
    # Create output directory if needed
    os.makedirs(os.path.dirname(output_filename), exist_ok=True)
    
    if frames:
        # Save as GIF
        imageio.mimsave(output_filename, frames, duration=durations, loop=0)
        print(f"Created animation: {output_filename}")
    else:
        print(f"Warning: No frames to save for {output_filename}")

def create_all_direction_gifs(animation_name, start_frame, animation_data=None, duration=5):
    """
    Create GIFs for all 8 directions of a specific animation
    
    Parameters:
    - animation_name: Name of the animation (for output filename)
    - start_frame: The starting frame number of this animation
    - animation_data: List of frame durations from frames.asm
    - duration: Number of frames per direction (default 5)
    """
    directions = ["up", "up_right", "right", "down_right", 
                 "down", "down_left", "left", "up_left"]
    
    # Create output directory
    output_dir = f"animations/{animation_name}"
    os.makedirs(output_dir, exist_ok=True)
    
    # For each direction, create a GIF
    for i, direction in enumerate(directions):
        output_file = f"{output_dir}/{animation_name}_{direction}.gif"
        create_animation_gif(
            start_frame=start_frame,
            end_frame=start_frame + (8 * duration) - 1,
            direction_num=i,
            output_filename=output_file,
            animation_data=animation_data
        )

# Example usage:
if __name__ == "__main__":
    # Animation timing data from frames.asm
    # SPAskatewp animation timings (see frames.asm line ~530)
    skatewp_timings = [10, 10, 10, 10, -15]  # Negative means loop back
    
    # SPAskate animation timings
    skate_timings = [10, 10, 10, 10, -15]

create_animation_gif(
    start_frame=0,
    end_frame=39,
    direction_num=2,  # 2 = right direction
    output_filename="animations/skating/skating_right.gif",
    animation_data=[10, 10, 10, 10, -15]  # Skating animation timing from frames.asm
)
# Out:
# Created animation: animations/skating/skating_right.gif

# %%
# Extract all unique Sprite Tile IDs and their corresponding size_tab values
unique_tile_data = set()

for frame in parser.frames:
    for sprite in frame.sprites:
        unique_tile_data.add((sprite.tile_id, sprite.size_tab))

# Sort the data by tile_id in descending order
sorted_tile_data = sorted(unique_tile_data, key=lambda x: x[0], reverse=True)

# Print the unique Tile IDs and size_tab values as hex
print(f"Unique Sprite Tile Data ({len(sorted_tile_data)}):")
for tile_id, size_tab in sorted_tile_data:
    print(f"Tile ID: 0x{tile_id:04X}, Size Tab: 0x{size_tab:04X}")
# Out:
# Unique Sprite Tile Data (1739):
# Tile ID: 0x5EF5, Size Tab: 0x0000
# Tile ID: 0x5CC0, Size Tab: 0x1000
# Tile ID: 0x5BD6, Size Tab: 0x2000
# Tile ID: 0x559F, Size Tab: 0x2000
# Tile ID: 0x53D0, Size Tab: 0x2000
# Tile ID: 0x50F4, Size Tab: 0x2000
# Tile ID: 0x50F2, Size Tab: 0x2000
# Tile ID: 0x5083, Size Tab: 0x2000
# Tile ID: 0x4F1C, Size Tab: 0x1500
# Tile ID: 0x4F18, Size Tab: 0x1500
# Tile ID: 0x4F14, Size Tab: 0x1500
# Tile ID: 0x4F10, Size Tab: 0x1500
# Tile ID: 0x4F0C, Size Tab: 0x1500
# Tile ID: 0x4EA8, Size Tab: 0x0300
# Tile ID: 0x4E06, Size Tab: 0x1900
# Tile ID: 0x4E00, Size Tab: 0x1900
# Tile ID: 0x4DDA, Size Tab: 0x2000
# Tile ID: 0x4DC9, Size Tab: 0x2000
# Tile ID: 0x4DB6, Size Tab: 0x2000
# Tile ID: 0x4D8B, Size Tab: 0x2000
# Tile ID: 0x4D48, Size Tab: 0x1D00
# Tile ID: 0x4D20, Size Tab: 0x2000
# Tile ID: 0x4CF0, Size Tab: 0x2000
# Tile ID: 0x4CA9, Size Tab: 0x2000
# Tile ID: 0x4C47, Size Tab: 0x2000
# Tile ID: 0x4C2F, Size Tab: 0x2000
# Tile ID: 0x4C2D, Size Tab: 0x2000
# Tile ID: 0x4C1E, Size Tab: 0x2000
# Tile ID: 0x4C1D, Size Tab: 0x2000
# Tile ID: 0x4C1C, Size Tab: 0x2000
# Tile ID: 0x4C1B, Size Tab: 0x2000
# Tile ID: 0x4C1A, Size Tab: 0x2000
# Tile ID: 0x4C19, Size Tab: 0x2000
# Tile ID: 0x4C18, Size Tab: 0x2000
# Tile ID: 0x4C17, Size Tab: 0x2000
# Tile ID: 0x4C16, Size Tab: 0x2000
# Tile ID: 0x4C15, Size Tab: 0x2000
# Tile ID: 0x4C14, Size Tab: 0x2000
# Tile ID: 0x4C13, Size Tab: 0x2000
# Tile ID: 0x4C12, Size Tab: 0x2000
# Tile ID: 0x4C11, Size Tab: 0x2000
# Tile ID: 0x4C10, Size Tab: 0x2000
# Tile ID: 0x4C0D, Size Tab: 0x2000
# Tile ID: 0x4C0A, Size Tab: 0x2000
# Tile ID: 0x4C09, Size Tab: 0x2000
# Tile ID: 0x4C08, Size Tab: 0x2000
# Tile ID: 0x4C07, Size Tab: 0x2000
# Tile ID: 0x4C06, Size Tab: 0x2000
# Tile ID: 0x4C05, Size Tab: 0x2000
# Tile ID: 0x4A90, Size Tab: 0x2400
# Tile ID: 0x4A74, Size Tab: 0x2400
# Tile ID: 0x4A70, Size Tab: 0x2400
# Tile ID: 0x4A6C, Size Tab: 0x2400
# Tile ID: 0x4A68, Size Tab: 0x2400
# Tile ID: 0x4A66, Size Tab: 0x2400
# Tile ID: 0x4A64, Size Tab: 0x2400
# Tile ID: 0x4A1C, Size Tab: 0x1600
# Tile ID: 0x4A16, Size Tab: 0x1600
# Tile ID: 0x49B0, Size Tab: 0x0700
# Tile ID: 0x49A8, Size Tab: 0x0700
# Tile ID: 0x49A0, Size Tab: 0x0700
# Tile ID: 0x499E, Size Tab: 0x2800
# Tile ID: 0x499B, Size Tab: 0x2800
# Tile ID: 0x4998, Size Tab: 0x2800
# Tile ID: 0x4948, Size Tab: 0x2C00
# Tile ID: 0x491E, Size Tab: 0x2000
# Tile ID: 0x4916, Size Tab: 0x2000
# Tile ID: 0x4898, Size Tab: 0x2100
# Tile ID: 0x4846, Size Tab: 0x2100
# Tile ID: 0x4842, Size Tab: 0x2100
# Tile ID: 0x483E, Size Tab: 0x2100
# Tile ID: 0x47FE, Size Tab: 0x1100
# Tile ID: 0x47F7, Size Tab: 0x0A00
# Tile ID: 0x47F0, Size Tab: 0x1500
# Tile ID: 0x47EC, Size Tab: 0x1500
# Tile ID: 0x47E8, Size Tab: 0x1500
# Tile ID: 0x47E4, Size Tab: 0x1500
# Tile ID: 0x47E0, Size Tab: 0x1500
# Tile ID: 0x47DC, Size Tab: 0x1500
# Tile ID: 0x47D8, Size Tab: 0x1500
# Tile ID: 0x47D4, Size Tab: 0x1500
# Tile ID: 0x47D0, Size Tab: 0x1500
# Tile ID: 0x47CC, Size Tab: 0x1500
# Tile ID: 0x47C8, Size Tab: 0x1500
# Tile ID: 0x47C4, Size Tab: 0x1500
# Tile ID: 0x47C0, Size Tab: 0x1500
# Tile ID: 0x47BC, Size Tab: 0x1500
# Tile ID: 0x47B8, Size Tab: 0x1500
# Tile ID: 0x47B4, Size Tab: 0x1500
# Tile ID: 0x47B0, Size Tab: 0x1500
# Tile ID: 0x47AC, Size Tab: 0x0E00
# Tile ID: 0x47AC, Size Tab: 0x1500
# Tile ID: 0x47A4, Size Tab: 0x1500
# Tile ID: 0x47A0, Size Tab: 0x0E00
# Tile ID: 0x4798, Size Tab: 0x1500
# Tile ID: 0x4794, Size Tab: 0x0E00
# Tile ID: 0x4790, Size Tab: 0x1500
# Tile ID: 0x478F, Size Tab: 0x1000
# Tile ID: 0x478C, Size Tab: 0x1500
# Tile ID: 0x4788, Size Tab: 0x0E00
# Tile ID: 0x4788, Size Tab: 0x1500
# Tile ID: 0x4784, Size Tab: 0x1500
# Tile ID: 0x4780, Size Tab: 0x1500
# Tile ID: 0x477C, Size Tab: 0x1500
# Tile ID: 0x477C, Size Tab: 0x0E00
# Tile ID: 0x4778, Size Tab: 0x1500
# Tile ID: 0x4774, Size Tab: 0x1500
# Tile ID: 0x4770, Size Tab: 0x1500
# Tile ID: 0x476C, Size Tab: 0x1500
# Tile ID: 0x4768, Size Tab: 0x1500
# Tile ID: 0x4764, Size Tab: 0x1500
# Tile ID: 0x4760, Size Tab: 0x1500
# Tile ID: 0x475C, Size Tab: 0x1500
# Tile ID: 0x4758, Size Tab: 0x1500
# Tile ID: 0x4754, Size Tab: 0x1500
# Tile ID: 0x4750, Size Tab: 0x1500
# Tile ID: 0x474C, Size Tab: 0x1500
# Tile ID: 0x4748, Size Tab: 0x1500
# Tile ID: 0x4744, Size Tab: 0x1500
# Tile ID: 0x4740, Size Tab: 0x1500
# Tile ID: 0x473C, Size Tab: 0x1500
# Tile ID: 0x4738, Size Tab: 0x1500
# Tile ID: 0x4734, Size Tab: 0x1500
# Tile ID: 0x4730, Size Tab: 0x1500
# Tile ID: 0x472C, Size Tab: 0x1500
# Tile ID: 0x4728, Size Tab: 0x1500
# Tile ID: 0x4724, Size Tab: 0x1500
# Tile ID: 0x4720, Size Tab: 0x1500
# Tile ID: 0x4700, Size Tab: 0x1500
# Tile ID: 0x46FC, Size Tab: 0x1500
# Tile ID: 0x46F8, Size Tab: 0x1500
# Tile ID: 0x46F4, Size Tab: 0x1500
# Tile ID: 0x46F0, Size Tab: 0x1500
# Tile ID: 0x46EC, Size Tab: 0x1500
# Tile ID: 0x46E8, Size Tab: 0x1500
# Tile ID: 0x46E4, Size Tab: 0x1500
# Tile ID: 0x46E0, Size Tab: 0x0000
# Tile ID: 0x46DE, Size Tab: 0x1900
# Tile ID: 0x46D8, Size Tab: 0x1900
# Tile ID: 0x46D2, Size Tab: 0x1900
# Tile ID: 0x46CC, Size Tab: 0x1900
# Tile ID: 0x46C6, Size Tab: 0x1900
# Tile ID: 0x46C0, Size Tab: 0x1900
# Tile ID: 0x46BA, Size Tab: 0x1900
# Tile ID: 0x46B8, Size Tab: 0x0300
# Tile ID: 0x46B4, Size Tab: 0x0300
# Tile ID: 0x46B4, Size Tab: 0x1900
# Tile ID: 0x46B0, Size Tab: 0x0300
# Tile ID: 0x46AE, Size Tab: 0x1900
# Tile ID: 0x46AC, Size Tab: 0x0300
# Tile ID: 0x46A8, Size Tab: 0x1900
# Tile ID: 0x46A2, Size Tab: 0x1900
# Tile ID: 0x46A0, Size Tab: 0x0700
# Tile ID: 0x469C, Size Tab: 0x1900
# Tile ID: 0x4698, Size Tab: 0x0700
# Tile ID: 0x4696, Size Tab: 0x1900
# Tile ID: 0x4690, Size Tab: 0x0700
# Tile ID: 0x4690, Size Tab: 0x1900
# Tile ID: 0x468A, Size Tab: 0x1900
# Tile ID: 0x4688, Size Tab: 0x0700
# Tile ID: 0x4684, Size Tab: 0x1900
# Tile ID: 0x4680, Size Tab: 0x0700
# Tile ID: 0x467E, Size Tab: 0x1900
# Tile ID: 0x4678, Size Tab: 0x0700
# Tile ID: 0x4678, Size Tab: 0x1900
# Tile ID: 0x4672, Size Tab: 0x1900
# Tile ID: 0x4670, Size Tab: 0x0700
# Tile ID: 0x466C, Size Tab: 0x1900
# Tile ID: 0x4668, Size Tab: 0x0700
# Tile ID: 0x4666, Size Tab: 0x1900
# Tile ID: 0x4660, Size Tab: 0x0700
# Tile ID: 0x4660, Size Tab: 0x1900
# Tile ID: 0x465A, Size Tab: 0x1900
# Tile ID: 0x4658, Size Tab: 0x0700
# Tile ID: 0x4654, Size Tab: 0x1900
# Tile ID: 0x4650, Size Tab: 0x0700
# Tile ID: 0x464E, Size Tab: 0x1900
# Tile ID: 0x4648, Size Tab: 0x0700
# Tile ID: 0x4648, Size Tab: 0x1900
# Tile ID: 0x4642, Size Tab: 0x1900
# Tile ID: 0x4640, Size Tab: 0x0700
# Tile ID: 0x463C, Size Tab: 0x1900
# Tile ID: 0x4638, Size Tab: 0x0700
# Tile ID: 0x4636, Size Tab: 0x1900
# Tile ID: 0x4630, Size Tab: 0x1900
# Tile ID: 0x4630, Size Tab: 0x0700
# Tile ID: 0x462A, Size Tab: 0x1900
# Tile ID: 0x4628, Size Tab: 0x0700
# Tile ID: 0x4624, Size Tab: 0x1900
# Tile ID: 0x4620, Size Tab: 0x0700
# Tile ID: 0x461E, Size Tab: 0x1900
# Tile ID: 0x4618, Size Tab: 0x1900
# Tile ID: 0x4618, Size Tab: 0x0700
# Tile ID: 0x4612, Size Tab: 0x1900
# Tile ID: 0x4610, Size Tab: 0x0700
# Tile ID: 0x460D, Size Tab: 0x2000
# Tile ID: 0x460C, Size Tab: 0x1900
# Tile ID: 0x460C, Size Tab: 0x2000
# Tile ID: 0x460B, Size Tab: 0x2000
# Tile ID: 0x460A, Size Tab: 0x2000
# Tile ID: 0x4609, Size Tab: 0x2000
# Tile ID: 0x4608, Size Tab: 0x2000
# Tile ID: 0x4608, Size Tab: 0x0700
# Tile ID: 0x4607, Size Tab: 0x2000
# Tile ID: 0x4606, Size Tab: 0x2000
# Tile ID: 0x4605, Size Tab: 0x2000
# Tile ID: 0x4604, Size Tab: 0x2000
# Tile ID: 0x4603, Size Tab: 0x2000
# Tile ID: 0x4602, Size Tab: 0x2000
# Tile ID: 0x4601, Size Tab: 0x2000
# Tile ID: 0x4600, Size Tab: 0x2000
# Tile ID: 0x4600, Size Tab: 0x0700
# Tile ID: 0x45FF, Size Tab: 0x2000
# Tile ID: 0x45FE, Size Tab: 0x2000
# Tile ID: 0x45FD, Size Tab: 0x2000
# Tile ID: 0x45FC, Size Tab: 0x2000
# Tile ID: 0x45FB, Size Tab: 0x2000
# Tile ID: 0x45FA, Size Tab: 0x2000
# Tile ID: 0x45F9, Size Tab: 0x2000
# Tile ID: 0x45F8, Size Tab: 0x2000
# Tile ID: 0x45F8, Size Tab: 0x0700
# Tile ID: 0x45F7, Size Tab: 0x2000
# Tile ID: 0x45F6, Size Tab: 0x2000
# Tile ID: 0x45F5, Size Tab: 0x2000
# Tile ID: 0x45F4, Size Tab: 0x2000
# Tile ID: 0x45F4, Size Tab: 0x1900
# Tile ID: 0x45F3, Size Tab: 0x2000
# Tile ID: 0x45F2, Size Tab: 0x2000
# Tile ID: 0x45F1, Size Tab: 0x2000
# Tile ID: 0x45F0, Size Tab: 0x0700
# Tile ID: 0x45F0, Size Tab: 0x2000
# Tile ID: 0x45EF, Size Tab: 0x2000
# Tile ID: 0x45EE, Size Tab: 0x1900
# Tile ID: 0x45EE, Size Tab: 0x2000
# Tile ID: 0x45ED, Size Tab: 0x2000
# Tile ID: 0x45EC, Size Tab: 0x2000
# Tile ID: 0x45EB, Size Tab: 0x2000
# Tile ID: 0x45EA, Size Tab: 0x2000
# Tile ID: 0x45E9, Size Tab: 0x2000
# Tile ID: 0x45E8, Size Tab: 0x2000
# Tile ID: 0x45E8, Size Tab: 0x1900
# Tile ID: 0x45E8, Size Tab: 0x0700
# Tile ID: 0x45E7, Size Tab: 0x2000
# Tile ID: 0x45E6, Size Tab: 0x2000
# Tile ID: 0x45E5, Size Tab: 0x2000
# Tile ID: 0x45E4, Size Tab: 0x2000
# Tile ID: 0x45E3, Size Tab: 0x2000
# Tile ID: 0x45E2, Size Tab: 0x2000
# Tile ID: 0x45E2, Size Tab: 0x1900
# Tile ID: 0x45E1, Size Tab: 0x2000
# Tile ID: 0x45E0, Size Tab: 0x0700
# Tile ID: 0x45E0, Size Tab: 0x2000
# Tile ID: 0x45DF, Size Tab: 0x2000
# Tile ID: 0x45DE, Size Tab: 0x2000
# Tile ID: 0x45DD, Size Tab: 0x2000
# Tile ID: 0x45DC, Size Tab: 0x2000
# Tile ID: 0x45DC, Size Tab: 0x1900
# Tile ID: 0x45DB, Size Tab: 0x2000
# Tile ID: 0x45DA, Size Tab: 0x2000
# Tile ID: 0x45D9, Size Tab: 0x2000
# Tile ID: 0x45D8, Size Tab: 0x2000
# Tile ID: 0x45D8, Size Tab: 0x0700
# Tile ID: 0x45D7, Size Tab: 0x2000
# Tile ID: 0x45D6, Size Tab: 0x2000
# Tile ID: 0x45D6, Size Tab: 0x1900
# Tile ID: 0x45D5, Size Tab: 0x2000
# Tile ID: 0x45D4, Size Tab: 0x2000
# Tile ID: 0x45D3, Size Tab: 0x2000
# Tile ID: 0x45D2, Size Tab: 0x2000
# Tile ID: 0x45D1, Size Tab: 0x2000
# Tile ID: 0x45D0, Size Tab: 0x2000
# Tile ID: 0x45D0, Size Tab: 0x1900
# Tile ID: 0x45D0, Size Tab: 0x0700
# Tile ID: 0x45CF, Size Tab: 0x2000
# Tile ID: 0x45CE, Size Tab: 0x2000
# Tile ID: 0x45CD, Size Tab: 0x2000
# Tile ID: 0x45CC, Size Tab: 0x2000
# Tile ID: 0x45CB, Size Tab: 0x2000
# Tile ID: 0x45CA, Size Tab: 0x2000
# Tile ID: 0x45CA, Size Tab: 0x1900
# Tile ID: 0x45C9, Size Tab: 0x2000
# Tile ID: 0x45C8, Size Tab: 0x2000
# Tile ID: 0x45C8, Size Tab: 0x0700
# Tile ID: 0x45C7, Size Tab: 0x2000
# Tile ID: 0x45C6, Size Tab: 0x2000
# Tile ID: 0x45C5, Size Tab: 0x2000
# Tile ID: 0x45C4, Size Tab: 0x1900
# Tile ID: 0x45C4, Size Tab: 0x2000
# Tile ID: 0x45C3, Size Tab: 0x2000
# Tile ID: 0x45C2, Size Tab: 0x2000
# Tile ID: 0x45C1, Size Tab: 0x2000
# Tile ID: 0x45C0, Size Tab: 0x2000
# Tile ID: 0x45C0, Size Tab: 0x0700
# Tile ID: 0x45BF, Size Tab: 0x2000
# Tile ID: 0x45BE, Size Tab: 0x2000
# Tile ID: 0x45BE, Size Tab: 0x1900
# Tile ID: 0x45BD, Size Tab: 0x2000
# Tile ID: 0x45BC, Size Tab: 0x2000
# Tile ID: 0x45BB, Size Tab: 0x2000
# Tile ID: 0x45BA, Size Tab: 0x2000
# Tile ID: 0x45B9, Size Tab: 0x2000
# Tile ID: 0x45B8, Size Tab: 0x2000
# Tile ID: 0x45B8, Size Tab: 0x1900
# Tile ID: 0x45B8, Size Tab: 0x0700
# Tile ID: 0x45B7, Size Tab: 0x2000
# Tile ID: 0x45B5, Size Tab: 0x2000
# Tile ID: 0x45B4, Size Tab: 0x2000
# Tile ID: 0x45B3, Size Tab: 0x2000
# Tile ID: 0x45B2, Size Tab: 0x2000
# Tile ID: 0x45B1, Size Tab: 0x2000
# Tile ID: 0x45B0, Size Tab: 0x2000
# Tile ID: 0x45B0, Size Tab: 0x1D00
# Tile ID: 0x45B0, Size Tab: 0x0700
# Tile ID: 0x45AF, Size Tab: 0x2000
# Tile ID: 0x45AE, Size Tab: 0x2000
# Tile ID: 0x45AD, Size Tab: 0x2000
# Tile ID: 0x45AC, Size Tab: 0x2000
# Tile ID: 0x45AB, Size Tab: 0x2000
# Tile ID: 0x45AA, Size Tab: 0x2000
# Tile ID: 0x45A9, Size Tab: 0x2000
# Tile ID: 0x45A8, Size Tab: 0x0700
# Tile ID: 0x45A8, Size Tab: 0x2000
# Tile ID: 0x45A8, Size Tab: 0x1D00
# Tile ID: 0x45A7, Size Tab: 0x2000
# Tile ID: 0x45A6, Size Tab: 0x2000
# Tile ID: 0x45A5, Size Tab: 0x2000
# Tile ID: 0x45A4, Size Tab: 0x2000
# Tile ID: 0x45A3, Size Tab: 0x2000
# Tile ID: 0x45A2, Size Tab: 0x2000
# Tile ID: 0x45A1, Size Tab: 0x2000
# Tile ID: 0x45A0, Size Tab: 0x2000
# Tile ID: 0x45A0, Size Tab: 0x1D00
# Tile ID: 0x45A0, Size Tab: 0x0700
# Tile ID: 0x459F, Size Tab: 0x2000
# Tile ID: 0x459E, Size Tab: 0x2000
# Tile ID: 0x459D, Size Tab: 0x2000
# Tile ID: 0x459C, Size Tab: 0x2000
# Tile ID: 0x459B, Size Tab: 0x2000
# Tile ID: 0x459A, Size Tab: 0x2000
# Tile ID: 0x4599, Size Tab: 0x2000
# Tile ID: 0x4598, Size Tab: 0x1D00
# Tile ID: 0x4598, Size Tab: 0x0700
# Tile ID: 0x4598, Size Tab: 0x2000
# Tile ID: 0x4597, Size Tab: 0x2000
# Tile ID: 0x4596, Size Tab: 0x2000
# Tile ID: 0x4595, Size Tab: 0x2000
# Tile ID: 0x4594, Size Tab: 0x2000
# Tile ID: 0x4593, Size Tab: 0x2000
# Tile ID: 0x4592, Size Tab: 0x2000
# Tile ID: 0x4591, Size Tab: 0x2000
# Tile ID: 0x4590, Size Tab: 0x2000
# Tile ID: 0x4590, Size Tab: 0x1D00
# Tile ID: 0x4590, Size Tab: 0x0700
# Tile ID: 0x458F, Size Tab: 0x2000
# Tile ID: 0x458E, Size Tab: 0x2000
# Tile ID: 0x458D, Size Tab: 0x2000
# Tile ID: 0x458C, Size Tab: 0x2000
# Tile ID: 0x458B, Size Tab: 0x2000
# Tile ID: 0x458A, Size Tab: 0x2000
# Tile ID: 0x4589, Size Tab: 0x2000
# Tile ID: 0x4588, Size Tab: 0x1D00
# Tile ID: 0x4588, Size Tab: 0x0700
# Tile ID: 0x4588, Size Tab: 0x2000
# Tile ID: 0x4587, Size Tab: 0x2000
# Tile ID: 0x4586, Size Tab: 0x2000
# Tile ID: 0x4585, Size Tab: 0x2000
# Tile ID: 0x4584, Size Tab: 0x2000
# Tile ID: 0x4583, Size Tab: 0x2000
# Tile ID: 0x4582, Size Tab: 0x2000
# Tile ID: 0x4581, Size Tab: 0x2000
# Tile ID: 0x4580, Size Tab: 0x2000
# Tile ID: 0x4580, Size Tab: 0x1D00
# Tile ID: 0x4580, Size Tab: 0x0700
# Tile ID: 0x457F, Size Tab: 0x2000
# Tile ID: 0x457E, Size Tab: 0x2000
# Tile ID: 0x457D, Size Tab: 0x2000
# Tile ID: 0x457C, Size Tab: 0x2000
# Tile ID: 0x457B, Size Tab: 0x2000
# Tile ID: 0x457A, Size Tab: 0x2000
# Tile ID: 0x4579, Size Tab: 0x2000
# Tile ID: 0x4578, Size Tab: 0x1D00
# Tile ID: 0x4578, Size Tab: 0x0700
# Tile ID: 0x4578, Size Tab: 0x2000
# Tile ID: 0x4577, Size Tab: 0x2000
# Tile ID: 0x4576, Size Tab: 0x2000
# Tile ID: 0x4575, Size Tab: 0x2000
# Tile ID: 0x4574, Size Tab: 0x2000
# Tile ID: 0x4573, Size Tab: 0x2000
# Tile ID: 0x4572, Size Tab: 0x2000
# Tile ID: 0x4571, Size Tab: 0x2000
# Tile ID: 0x4570, Size Tab: 0x2000
# Tile ID: 0x4570, Size Tab: 0x1D00
# Tile ID: 0x4570, Size Tab: 0x0700
# Tile ID: 0x456F, Size Tab: 0x2000
# Tile ID: 0x456E, Size Tab: 0x2000
# Tile ID: 0x456D, Size Tab: 0x2000
# Tile ID: 0x456C, Size Tab: 0x2000
# Tile ID: 0x456B, Size Tab: 0x2000
# Tile ID: 0x456A, Size Tab: 0x2000
# Tile ID: 0x4569, Size Tab: 0x2000
# Tile ID: 0x4568, Size Tab: 0x2000
# Tile ID: 0x4568, Size Tab: 0x1D00
# Tile ID: 0x4568, Size Tab: 0x0700
# Tile ID: 0x4567, Size Tab: 0x2000
# Tile ID: 0x4566, Size Tab: 0x2000
# Tile ID: 0x4565, Size Tab: 0x2000
# Tile ID: 0x4564, Size Tab: 0x2000
# Tile ID: 0x4563, Size Tab: 0x2000
# Tile ID: 0x4562, Size Tab: 0x2000
# Tile ID: 0x4561, Size Tab: 0x2000
# Tile ID: 0x4560, Size Tab: 0x2000
# Tile ID: 0x4560, Size Tab: 0x1D00
# Tile ID: 0x4560, Size Tab: 0x0700
# Tile ID: 0x455F, Size Tab: 0x2000
# Tile ID: 0x455E, Size Tab: 0x2000
# Tile ID: 0x455D, Size Tab: 0x2000
# Tile ID: 0x455C, Size Tab: 0x2000
# Tile ID: 0x4558, Size Tab: 0x1D00
# Tile ID: 0x4558, Size Tab: 0x2000
# Tile ID: 0x4558, Size Tab: 0x0700
# Tile ID: 0x4555, Size Tab: 0x2000
# Tile ID: 0x4554, Size Tab: 0x2000
# Tile ID: 0x4551, Size Tab: 0x2000
# Tile ID: 0x4550, Size Tab: 0x1D00
# Tile ID: 0x4550, Size Tab: 0x0700
# Tile ID: 0x454E, Size Tab: 0x2000
# Tile ID: 0x4549, Size Tab: 0x2000
# Tile ID: 0x4548, Size Tab: 0x0700
# Tile ID: 0x4546, Size Tab: 0x2000
# Tile ID: 0x4544, Size Tab: 0x2000
# Tile ID: 0x4543, Size Tab: 0x2000
# Tile ID: 0x4542, Size Tab: 0x2000
# Tile ID: 0x4541, Size Tab: 0x2000
# Tile ID: 0x4540, Size Tab: 0x2000
# Tile ID: 0x4540, Size Tab: 0x1D00
# Tile ID: 0x4540, Size Tab: 0x0700
# Tile ID: 0x453F, Size Tab: 0x2000
# Tile ID: 0x453E, Size Tab: 0x2000
# Tile ID: 0x453D, Size Tab: 0x2000
# Tile ID: 0x453C, Size Tab: 0x2000
# Tile ID: 0x453B, Size Tab: 0x2000
# Tile ID: 0x453A, Size Tab: 0x2000
# Tile ID: 0x4539, Size Tab: 0x2000
# Tile ID: 0x4538, Size Tab: 0x1D00
# Tile ID: 0x4538, Size Tab: 0x0700
# Tile ID: 0x4538, Size Tab: 0x2000
# Tile ID: 0x4537, Size Tab: 0x2000
# Tile ID: 0x4536, Size Tab: 0x2000
# Tile ID: 0x4535, Size Tab: 0x2000
# Tile ID: 0x4534, Size Tab: 0x2000
# Tile ID: 0x4533, Size Tab: 0x2000
# Tile ID: 0x4532, Size Tab: 0x2000
# Tile ID: 0x4531, Size Tab: 0x2000
# Tile ID: 0x4530, Size Tab: 0x2000
# Tile ID: 0x4530, Size Tab: 0x1D00
# Tile ID: 0x4530, Size Tab: 0x0700
# Tile ID: 0x452F, Size Tab: 0x2000
# Tile ID: 0x452E, Size Tab: 0x2000
# Tile ID: 0x452D, Size Tab: 0x2000
# Tile ID: 0x452C, Size Tab: 0x2000
# Tile ID: 0x452B, Size Tab: 0x2000
# Tile ID: 0x452A, Size Tab: 0x2000
# Tile ID: 0x4529, Size Tab: 0x2000
# Tile ID: 0x4528, Size Tab: 0x2000
# Tile ID: 0x4528, Size Tab: 0x0700
# Tile ID: 0x4528, Size Tab: 0x1D00
# Tile ID: 0x4527, Size Tab: 0x2000
# Tile ID: 0x4526, Size Tab: 0x2000
# Tile ID: 0x4525, Size Tab: 0x2000
# Tile ID: 0x4524, Size Tab: 0x2000
# Tile ID: 0x4523, Size Tab: 0x2000
# Tile ID: 0x4522, Size Tab: 0x2000
# Tile ID: 0x4521, Size Tab: 0x2000
# Tile ID: 0x4520, Size Tab: 0x2000
# Tile ID: 0x4520, Size Tab: 0x0700
# Tile ID: 0x4520, Size Tab: 0x1D00
# Tile ID: 0x451F, Size Tab: 0x2000
# Tile ID: 0x451E, Size Tab: 0x2000
# Tile ID: 0x451D, Size Tab: 0x2000
# Tile ID: 0x451C, Size Tab: 0x2000
# Tile ID: 0x451B, Size Tab: 0x2000
# Tile ID: 0x451A, Size Tab: 0x2000
# Tile ID: 0x4519, Size Tab: 0x2000
# Tile ID: 0x4518, Size Tab: 0x0700
# Tile ID: 0x4518, Size Tab: 0x2000
# Tile ID: 0x4518, Size Tab: 0x1D00
# Tile ID: 0x4517, Size Tab: 0x2000
# Tile ID: 0x4516, Size Tab: 0x2000
# Tile ID: 0x4515, Size Tab: 0x2000
# Tile ID: 0x4514, Size Tab: 0x2000
# Tile ID: 0x4513, Size Tab: 0x2000
# Tile ID: 0x4512, Size Tab: 0x2000
# Tile ID: 0x4511, Size Tab: 0x2000
# Tile ID: 0x4510, Size Tab: 0x1D00
# Tile ID: 0x4510, Size Tab: 0x0700
# Tile ID: 0x4510, Size Tab: 0x2000
# Tile ID: 0x450F, Size Tab: 0x2000
# Tile ID: 0x450E, Size Tab: 0x2000
# Tile ID: 0x450D, Size Tab: 0x2000
# Tile ID: 0x450C, Size Tab: 0x2000
# Tile ID: 0x450B, Size Tab: 0x2000
# Tile ID: 0x450A, Size Tab: 0x2000
# Tile ID: 0x4509, Size Tab: 0x2000
# Tile ID: 0x4508, Size Tab: 0x1D00
# Tile ID: 0x4508, Size Tab: 0x0700
# Tile ID: 0x4508, Size Tab: 0x2000
# Tile ID: 0x4507, Size Tab: 0x2000
# Tile ID: 0x4506, Size Tab: 0x2000
# Tile ID: 0x4505, Size Tab: 0x2000
# Tile ID: 0x4503, Size Tab: 0x2000
# Tile ID: 0x4502, Size Tab: 0x2000
# Tile ID: 0x4501, Size Tab: 0x2000
# Tile ID: 0x4500, Size Tab: 0x2000
# Tile ID: 0x4500, Size Tab: 0x1D00
# Tile ID: 0x4500, Size Tab: 0x0700
# Tile ID: 0x44FF, Size Tab: 0x2000
# Tile ID: 0x44FE, Size Tab: 0x2000
# Tile ID: 0x44FD, Size Tab: 0x2000
# Tile ID: 0x44FC, Size Tab: 0x2000
# Tile ID: 0x44FB, Size Tab: 0x2000
# Tile ID: 0x44FA, Size Tab: 0x2000
# Tile ID: 0x44F9, Size Tab: 0x2000
# Tile ID: 0x44F8, Size Tab: 0x1D00
# Tile ID: 0x44F8, Size Tab: 0x0700
# Tile ID: 0x44F8, Size Tab: 0x2000
# Tile ID: 0x44F7, Size Tab: 0x2000
# Tile ID: 0x44F6, Size Tab: 0x2000
# Tile ID: 0x44F5, Size Tab: 0x2000
# Tile ID: 0x44F4, Size Tab: 0x2000
# Tile ID: 0x44F3, Size Tab: 0x2000
# Tile ID: 0x44F2, Size Tab: 0x2000
# Tile ID: 0x44F1, Size Tab: 0x2000
# Tile ID: 0x44F0, Size Tab: 0x2000
# Tile ID: 0x44F0, Size Tab: 0x1D00
# Tile ID: 0x44F0, Size Tab: 0x0700
# Tile ID: 0x44EF, Size Tab: 0x2000
# Tile ID: 0x44EE, Size Tab: 0x2000
# Tile ID: 0x44ED, Size Tab: 0x2000
# Tile ID: 0x44EC, Size Tab: 0x2000
# Tile ID: 0x44EB, Size Tab: 0x2000
# Tile ID: 0x44EA, Size Tab: 0x2000
# Tile ID: 0x44E8, Size Tab: 0x2000
# Tile ID: 0x44E8, Size Tab: 0x1D00
# Tile ID: 0x44E8, Size Tab: 0x0700
# Tile ID: 0x44E7, Size Tab: 0x2000
# Tile ID: 0x44E6, Size Tab: 0x2000
# Tile ID: 0x44E5, Size Tab: 0x2000
# Tile ID: 0x44E3, Size Tab: 0x2000
# Tile ID: 0x44E2, Size Tab: 0x2000
# Tile ID: 0x44E1, Size Tab: 0x2000
# Tile ID: 0x44E0, Size Tab: 0x2000
# Tile ID: 0x44E0, Size Tab: 0x0700
# Tile ID: 0x44DF, Size Tab: 0x2000
# Tile ID: 0x44DE, Size Tab: 0x2000
# Tile ID: 0x44DD, Size Tab: 0x2000
# Tile ID: 0x44DC, Size Tab: 0x2000
# Tile ID: 0x44DB, Size Tab: 0x2000
# Tile ID: 0x44DA, Size Tab: 0x1200
# Tile ID: 0x44DA, Size Tab: 0x2000
# Tile ID: 0x44D9, Size Tab: 0x2000
# Tile ID: 0x44D8, Size Tab: 0x2000
# Tile ID: 0x44D8, Size Tab: 0x0700
# Tile ID: 0x44D7, Size Tab: 0x1200
# Tile ID: 0x44D7, Size Tab: 0x2000
# Tile ID: 0x44D6, Size Tab: 0x2000
# Tile ID: 0x44D5, Size Tab: 0x2000
# Tile ID: 0x44D4, Size Tab: 0x1200
# Tile ID: 0x44D4, Size Tab: 0x2000
# Tile ID: 0x44D3, Size Tab: 0x2000
# Tile ID: 0x44D2, Size Tab: 0x2000
# Tile ID: 0x44D1, Size Tab: 0x1200
# Tile ID: 0x44D1, Size Tab: 0x2000
# Tile ID: 0x44D0, Size Tab: 0x2000
# Tile ID: 0x44D0, Size Tab: 0x0700
# Tile ID: 0x44CF, Size Tab: 0x2000
# Tile ID: 0x44CE, Size Tab: 0x1200
# Tile ID: 0x44CE, Size Tab: 0x2000
# Tile ID: 0x44CD, Size Tab: 0x2000
# Tile ID: 0x44CC, Size Tab: 0x2000
# Tile ID: 0x44CB, Size Tab: 0x1200
# Tile ID: 0x44CB, Size Tab: 0x2000
# Tile ID: 0x44CA, Size Tab: 0x2000
# Tile ID: 0x44C9, Size Tab: 0x2000
# Tile ID: 0x44C8, Size Tab: 0x0700
# Tile ID: 0x44C8, Size Tab: 0x1200
# Tile ID: 0x44C8, Size Tab: 0x2000
# Tile ID: 0x44C7, Size Tab: 0x2000
# Tile ID: 0x44C6, Size Tab: 0x2000
# Tile ID: 0x44C5, Size Tab: 0x1200
# Tile ID: 0x44C5, Size Tab: 0x2000
# Tile ID: 0x44C4, Size Tab: 0x2000
# Tile ID: 0x44C3, Size Tab: 0x2000
# Tile ID: 0x44C2, Size Tab: 0x1200
# Tile ID: 0x44C2, Size Tab: 0x2000
# Tile ID: 0x44C1, Size Tab: 0x2000
# Tile ID: 0x44C0, Size Tab: 0x0700
# Tile ID: 0x44C0, Size Tab: 0x2000
# Tile ID: 0x44BF, Size Tab: 0x1200
# Tile ID: 0x44BF, Size Tab: 0x2000
# Tile ID: 0x44BE, Size Tab: 0x2000
# Tile ID: 0x44BD, Size Tab: 0x2000
# Tile ID: 0x44BC, Size Tab: 0x1200
# Tile ID: 0x44BC, Size Tab: 0x2000
# Tile ID: 0x44BB, Size Tab: 0x2000
# Tile ID: 0x44BA, Size Tab: 0x2000
# Tile ID: 0x44B9, Size Tab: 0x1200
# Tile ID: 0x44B9, Size Tab: 0x2000
# Tile ID: 0x44B8, Size Tab: 0x0700
# Tile ID: 0x44B8, Size Tab: 0x2000
# Tile ID: 0x44B7, Size Tab: 0x2000
# Tile ID: 0x44B6, Size Tab: 0x1200
# Tile ID: 0x44B6, Size Tab: 0x2000
# Tile ID: 0x44B5, Size Tab: 0x2000
# Tile ID: 0x44B4, Size Tab: 0x2000
# Tile ID: 0x44B3, Size Tab: 0x1200
# Tile ID: 0x44B3, Size Tab: 0x2000
# Tile ID: 0x44B2, Size Tab: 0x2000
# Tile ID: 0x44B1, Size Tab: 0x2000
# Tile ID: 0x44B0, Size Tab: 0x0700
# Tile ID: 0x44B0, Size Tab: 0x1200
# Tile ID: 0x44B0, Size Tab: 0x2000
# Tile ID: 0x44AF, Size Tab: 0x2000
# Tile ID: 0x44AE, Size Tab: 0x2000
# Tile ID: 0x44AD, Size Tab: 0x1200
# Tile ID: 0x44AD, Size Tab: 0x2000
# Tile ID: 0x44AC, Size Tab: 0x2000
# Tile ID: 0x44AB, Size Tab: 0x2000
# Tile ID: 0x44AA, Size Tab: 0x1200
# Tile ID: 0x44AA, Size Tab: 0x2000
# Tile ID: 0x44A9, Size Tab: 0x2000
# Tile ID: 0x44A8, Size Tab: 0x2000
# Tile ID: 0x44A8, Size Tab: 0x0700
# Tile ID: 0x44A7, Size Tab: 0x1200
# Tile ID: 0x44A7, Size Tab: 0x2000
# Tile ID: 0x44A6, Size Tab: 0x2000
# Tile ID: 0x44A5, Size Tab: 0x2000
# Tile ID: 0x44A4, Size Tab: 0x1200
# Tile ID: 0x44A4, Size Tab: 0x2000
# Tile ID: 0x44A3, Size Tab: 0x2000
# Tile ID: 0x44A2, Size Tab: 0x2000
# Tile ID: 0x44A1, Size Tab: 0x1200
# Tile ID: 0x44A1, Size Tab: 0x2000
# Tile ID: 0x44A0, Size Tab: 0x0700
# Tile ID: 0x44A0, Size Tab: 0x2000
# Tile ID: 0x449F, Size Tab: 0x2000
# Tile ID: 0x449E, Size Tab: 0x1200
# Tile ID: 0x449E, Size Tab: 0x2000
# Tile ID: 0x449D, Size Tab: 0x2000
# Tile ID: 0x449C, Size Tab: 0x2000
# Tile ID: 0x449B, Size Tab: 0x1200
# Tile ID: 0x449B, Size Tab: 0x2000
# Tile ID: 0x449A, Size Tab: 0x2000
# Tile ID: 0x4499, Size Tab: 0x2000
# Tile ID: 0x4498, Size Tab: 0x1200
# Tile ID: 0x4498, Size Tab: 0x2000
# Tile ID: 0x4498, Size Tab: 0x0700
# Tile ID: 0x4497, Size Tab: 0x2000
# Tile ID: 0x4496, Size Tab: 0x2000
# Tile ID: 0x4495, Size Tab: 0x1200
# Tile ID: 0x4495, Size Tab: 0x2000
# Tile ID: 0x4494, Size Tab: 0x2000
# Tile ID: 0x4493, Size Tab: 0x2000
# Tile ID: 0x4492, Size Tab: 0x1200
# Tile ID: 0x4492, Size Tab: 0x2000
# Tile ID: 0x4491, Size Tab: 0x2000
# Tile ID: 0x4490, Size Tab: 0x0700
# Tile ID: 0x4490, Size Tab: 0x2000
# Tile ID: 0x448F, Size Tab: 0x1200
# Tile ID: 0x448F, Size Tab: 0x2000
# Tile ID: 0x448E, Size Tab: 0x2000
# Tile ID: 0x448D, Size Tab: 0x2000
# Tile ID: 0x448C, Size Tab: 0x1200
# Tile ID: 0x448C, Size Tab: 0x2000
# Tile ID: 0x448B, Size Tab: 0x2000
# Tile ID: 0x448A, Size Tab: 0x2000
# Tile ID: 0x4489, Size Tab: 0x2000
# Tile ID: 0x4489, Size Tab: 0x1200
# Tile ID: 0x4488, Size Tab: 0x2000
# Tile ID: 0x4488, Size Tab: 0x0700
# Tile ID: 0x4487, Size Tab: 0x2000
# Tile ID: 0x4486, Size Tab: 0x1200
# Tile ID: 0x4486, Size Tab: 0x2000
# Tile ID: 0x4485, Size Tab: 0x2000
# Tile ID: 0x4484, Size Tab: 0x2000
# Tile ID: 0x4483, Size Tab: 0x1200
# Tile ID: 0x4483, Size Tab: 0x2000
# Tile ID: 0x4482, Size Tab: 0x2000
# Tile ID: 0x4481, Size Tab: 0x2000
# Tile ID: 0x4480, Size Tab: 0x0700
# Tile ID: 0x4480, Size Tab: 0x1200
# Tile ID: 0x4480, Size Tab: 0x2000
# Tile ID: 0x447F, Size Tab: 0x2000
# Tile ID: 0x447E, Size Tab: 0x2000
# Tile ID: 0x447D, Size Tab: 0x1200
# Tile ID: 0x447D, Size Tab: 0x2000
# Tile ID: 0x447C, Size Tab: 0x2000
# Tile ID: 0x447B, Size Tab: 0x2000
# Tile ID: 0x447A, Size Tab: 0x1200
# Tile ID: 0x447A, Size Tab: 0x2000
# Tile ID: 0x4479, Size Tab: 0x2000
# Tile ID: 0x4478, Size Tab: 0x2000
# Tile ID: 0x4478, Size Tab: 0x0700
# Tile ID: 0x4477, Size Tab: 0x2000
# Tile ID: 0x4477, Size Tab: 0x1200
# Tile ID: 0x4476, Size Tab: 0x2000
# Tile ID: 0x4475, Size Tab: 0x2000
# Tile ID: 0x4474, Size Tab: 0x1200
# Tile ID: 0x4474, Size Tab: 0x2000
# Tile ID: 0x4473, Size Tab: 0x2000
# Tile ID: 0x4472, Size Tab: 0x2000
# Tile ID: 0x4471, Size Tab: 0x1200
# Tile ID: 0x4471, Size Tab: 0x2000
# Tile ID: 0x4470, Size Tab: 0x0700
# Tile ID: 0x4470, Size Tab: 0x2000
# Tile ID: 0x446F, Size Tab: 0x2000
# Tile ID: 0x446E, Size Tab: 0x1200
# Tile ID: 0x446E, Size Tab: 0x2000
# Tile ID: 0x446D, Size Tab: 0x2000
# Tile ID: 0x446C, Size Tab: 0x2000
# Tile ID: 0x446B, Size Tab: 0x2000
# Tile ID: 0x446B, Size Tab: 0x1200
# Tile ID: 0x446A, Size Tab: 0x2000
# Tile ID: 0x4469, Size Tab: 0x2000
# Tile ID: 0x4468, Size Tab: 0x2000
# Tile ID: 0x4468, Size Tab: 0x0700
# Tile ID: 0x4468, Size Tab: 0x1200
# Tile ID: 0x4467, Size Tab: 0x2000
# Tile ID: 0x4466, Size Tab: 0x2000
# Tile ID: 0x4465, Size Tab: 0x1200
# Tile ID: 0x4465, Size Tab: 0x2000
# Tile ID: 0x4464, Size Tab: 0x2000
# Tile ID: 0x4463, Size Tab: 0x2000
# Tile ID: 0x4462, Size Tab: 0x1200
# Tile ID: 0x4462, Size Tab: 0x2000
# Tile ID: 0x4461, Size Tab: 0x2000
# Tile ID: 0x4460, Size Tab: 0x0700
# Tile ID: 0x4460, Size Tab: 0x2000
# Tile ID: 0x445F, Size Tab: 0x1200
# Tile ID: 0x445F, Size Tab: 0x2000
# Tile ID: 0x445E, Size Tab: 0x2000
# Tile ID: 0x445D, Size Tab: 0x2000
# Tile ID: 0x445C, Size Tab: 0x1200
# Tile ID: 0x445C, Size Tab: 0x2000
# Tile ID: 0x445B, Size Tab: 0x2000
# Tile ID: 0x445A, Size Tab: 0x2000
# Tile ID: 0x4459, Size Tab: 0x2000
# Tile ID: 0x4459, Size Tab: 0x1200
# Tile ID: 0x4458, Size Tab: 0x2000
# Tile ID: 0x4458, Size Tab: 0x0700
# Tile ID: 0x4457, Size Tab: 0x2000
# Tile ID: 0x4456, Size Tab: 0x2000
# Tile ID: 0x4456, Size Tab: 0x1200
# Tile ID: 0x4455, Size Tab: 0x2000
# Tile ID: 0x4454, Size Tab: 0x2000
# Tile ID: 0x4453, Size Tab: 0x1200
# Tile ID: 0x4453, Size Tab: 0x2000
# Tile ID: 0x4452, Size Tab: 0x2000
# Tile ID: 0x4451, Size Tab: 0x2000
# Tile ID: 0x4450, Size Tab: 0x0700
# Tile ID: 0x4450, Size Tab: 0x1200
# Tile ID: 0x4450, Size Tab: 0x2000
# Tile ID: 0x444F, Size Tab: 0x2000
# Tile ID: 0x444E, Size Tab: 0x2000
# Tile ID: 0x444D, Size Tab: 0x2000
# Tile ID: 0x444C, Size Tab: 0x2000
# Tile ID: 0x444B, Size Tab: 0x2000
# Tile ID: 0x444A, Size Tab: 0x2000
# Tile ID: 0x444A, Size Tab: 0x1600
# Tile ID: 0x4449, Size Tab: 0x2000
# Tile ID: 0x4448, Size Tab: 0x2000
# Tile ID: 0x4448, Size Tab: 0x0700
# Tile ID: 0x4447, Size Tab: 0x2000
# Tile ID: 0x4446, Size Tab: 0x2000
# Tile ID: 0x4445, Size Tab: 0x2000
# Tile ID: 0x4444, Size Tab: 0x1600
# Tile ID: 0x4444, Size Tab: 0x2000
# Tile ID: 0x4443, Size Tab: 0x2000
# Tile ID: 0x4442, Size Tab: 0x2000
# Tile ID: 0x4441, Size Tab: 0x2000
# Tile ID: 0x4440, Size Tab: 0x2000
# Tile ID: 0x4440, Size Tab: 0x0700
# Tile ID: 0x443F, Size Tab: 0x2000
# Tile ID: 0x443E, Size Tab: 0x1600
# Tile ID: 0x443E, Size Tab: 0x2000
# Tile ID: 0x443D, Size Tab: 0x2000
# Tile ID: 0x443C, Size Tab: 0x2000
# Tile ID: 0x443B, Size Tab: 0x2000
# Tile ID: 0x443A, Size Tab: 0x2000
# Tile ID: 0x4439, Size Tab: 0x2000
# Tile ID: 0x4438, Size Tab: 0x2000
# Tile ID: 0x4438, Size Tab: 0x0700
# Tile ID: 0x4438, Size Tab: 0x1600
# Tile ID: 0x4437, Size Tab: 0x2000
# Tile ID: 0x4436, Size Tab: 0x2000
# Tile ID: 0x4435, Size Tab: 0x2000
# Tile ID: 0x4434, Size Tab: 0x2000
# Tile ID: 0x4433, Size Tab: 0x2000
# Tile ID: 0x4432, Size Tab: 0x1600
# Tile ID: 0x4432, Size Tab: 0x2000
# Tile ID: 0x4431, Size Tab: 0x2000
# Tile ID: 0x4430, Size Tab: 0x2000
# Tile ID: 0x4430, Size Tab: 0x0700
# Tile ID: 0x442F, Size Tab: 0x2000
# Tile ID: 0x442E, Size Tab: 0x2000
# Tile ID: 0x442D, Size Tab: 0x2000
# Tile ID: 0x442C, Size Tab: 0x1600
# Tile ID: 0x442C, Size Tab: 0x2000
# Tile ID: 0x442B, Size Tab: 0x2000
# Tile ID: 0x442A, Size Tab: 0x2000
# Tile ID: 0x4429, Size Tab: 0x2000
# Tile ID: 0x4428, Size Tab: 0x0700
# Tile ID: 0x4428, Size Tab: 0x2000
# Tile ID: 0x4427, Size Tab: 0x2000
# Tile ID: 0x4426, Size Tab: 0x1600
# Tile ID: 0x4426, Size Tab: 0x2000
# Tile ID: 0x4425, Size Tab: 0x2000
# Tile ID: 0x4424, Size Tab: 0x2000
# Tile ID: 0x4423, Size Tab: 0x2000
# Tile ID: 0x4422, Size Tab: 0x2000
# Tile ID: 0x4421, Size Tab: 0x2000
# Tile ID: 0x4420, Size Tab: 0x0700
# Tile ID: 0x4420, Size Tab: 0x1600
# Tile ID: 0x4420, Size Tab: 0x2000
# Tile ID: 0x441F, Size Tab: 0x2000
# Tile ID: 0x441A, Size Tab: 0x1600
# Tile ID: 0x4418, Size Tab: 0x0700
# Tile ID: 0x4414, Size Tab: 0x1600
# Tile ID: 0x4410, Size Tab: 0x0700
# Tile ID: 0x440F, Size Tab: 0x2000
# Tile ID: 0x440E, Size Tab: 0x1600
# Tile ID: 0x440E, Size Tab: 0x2000
# Tile ID: 0x440D, Size Tab: 0x2000
# Tile ID: 0x440C, Size Tab: 0x2000
# Tile ID: 0x440B, Size Tab: 0x2000
# Tile ID: 0x4408, Size Tab: 0x0700
# Tile ID: 0x4408, Size Tab: 0x1600
# Tile ID: 0x4402, Size Tab: 0x1600
# Tile ID: 0x4400, Size Tab: 0x0700
# Tile ID: 0x43FC, Size Tab: 0x1600
# Tile ID: 0x43FB, Size Tab: 0x2000
# Tile ID: 0x43FA, Size Tab: 0x2000
# Tile ID: 0x43F9, Size Tab: 0x2000
# Tile ID: 0x43F8, Size Tab: 0x2000
# Tile ID: 0x43F8, Size Tab: 0x0700
# Tile ID: 0x43F7, Size Tab: 0x2000
# Tile ID: 0x43F6, Size Tab: 0x2000
# Tile ID: 0x43F6, Size Tab: 0x1600
# Tile ID: 0x43F5, Size Tab: 0x2000
# Tile ID: 0x43F4, Size Tab: 0x2000
# Tile ID: 0x43F3, Size Tab: 0x2000
# Tile ID: 0x43F2, Size Tab: 0x2000
# Tile ID: 0x43F1, Size Tab: 0x2000
# Tile ID: 0x43F0, Size Tab: 0x1600
# Tile ID: 0x43F0, Size Tab: 0x2000
# Tile ID: 0x43F0, Size Tab: 0x0700
# Tile ID: 0x43EF, Size Tab: 0x2000
# Tile ID: 0x43EE, Size Tab: 0x2000
# Tile ID: 0x43ED, Size Tab: 0x2000
# Tile ID: 0x43EC, Size Tab: 0x2000
# Tile ID: 0x43EB, Size Tab: 0x2000
# Tile ID: 0x43EA, Size Tab: 0x1600
# Tile ID: 0x43EA, Size Tab: 0x2000
# Tile ID: 0x43E9, Size Tab: 0x2000
# Tile ID: 0x43E8, Size Tab: 0x0700
# Tile ID: 0x43E8, Size Tab: 0x2000
# Tile ID: 0x43E7, Size Tab: 0x2000
# Tile ID: 0x43E6, Size Tab: 0x2000
# Tile ID: 0x43E5, Size Tab: 0x2000
# Tile ID: 0x43E4, Size Tab: 0x2000
# Tile ID: 0x43E4, Size Tab: 0x1600
# Tile ID: 0x43E3, Size Tab: 0x2000
# Tile ID: 0x43E2, Size Tab: 0x2000
# Tile ID: 0x43E1, Size Tab: 0x2000
# Tile ID: 0x43E0, Size Tab: 0x0700
# Tile ID: 0x43E0, Size Tab: 0x2000
# Tile ID: 0x43DF, Size Tab: 0x2000
# Tile ID: 0x43DE, Size Tab: 0x1600
# Tile ID: 0x43DE, Size Tab: 0x2000
# Tile ID: 0x43DD, Size Tab: 0x2000
# Tile ID: 0x43DC, Size Tab: 0x2000
# Tile ID: 0x43DB, Size Tab: 0x2000
# Tile ID: 0x43DA, Size Tab: 0x2000
# Tile ID: 0x43D9, Size Tab: 0x2000
# Tile ID: 0x43D8, Size Tab: 0x0700
# Tile ID: 0x43D8, Size Tab: 0x1600
# Tile ID: 0x43D8, Size Tab: 0x2000
# Tile ID: 0x43D7, Size Tab: 0x2000
# Tile ID: 0x43D5, Size Tab: 0x2000
# Tile ID: 0x43D4, Size Tab: 0x2000
# Tile ID: 0x43D3, Size Tab: 0x2000
# Tile ID: 0x43D2, Size Tab: 0x1600
# Tile ID: 0x43D2, Size Tab: 0x2000
# Tile ID: 0x43D1, Size Tab: 0x2000
# Tile ID: 0x43D0, Size Tab: 0x0700
# Tile ID: 0x43CF, Size Tab: 0x2000
# Tile ID: 0x43CE, Size Tab: 0x2000
# Tile ID: 0x43CD, Size Tab: 0x2000
# Tile ID: 0x43CC, Size Tab: 0x1600
# Tile ID: 0x43CC, Size Tab: 0x2000
# Tile ID: 0x43CB, Size Tab: 0x2000
# Tile ID: 0x43CA, Size Tab: 0x2000
# Tile ID: 0x43C9, Size Tab: 0x2000
# Tile ID: 0x43C8, Size Tab: 0x0700
# Tile ID: 0x43C8, Size Tab: 0x2000
# Tile ID: 0x43C7, Size Tab: 0x2000
# Tile ID: 0x43C6, Size Tab: 0x2000
# Tile ID: 0x43C6, Size Tab: 0x1600
# Tile ID: 0x43C5, Size Tab: 0x2000
# Tile ID: 0x43C4, Size Tab: 0x2000
# Tile ID: 0x43C3, Size Tab: 0x2000
# Tile ID: 0x43C2, Size Tab: 0x2000
# Tile ID: 0x43C1, Size Tab: 0x2000
# Tile ID: 0x43C0, Size Tab: 0x2000
# Tile ID: 0x43C0, Size Tab: 0x0700
# Tile ID: 0x43C0, Size Tab: 0x1600
# Tile ID: 0x43BF, Size Tab: 0x2000
# Tile ID: 0x43BE, Size Tab: 0x2000
# Tile ID: 0x43BD, Size Tab: 0x2000
# Tile ID: 0x43BC, Size Tab: 0x2000
# Tile ID: 0x43BB, Size Tab: 0x2000
# Tile ID: 0x43BA, Size Tab: 0x1600
# Tile ID: 0x43BA, Size Tab: 0x2000
# Tile ID: 0x43B9, Size Tab: 0x2000
# Tile ID: 0x43B8, Size Tab: 0x0700
# Tile ID: 0x43B8, Size Tab: 0x2000
# Tile ID: 0x43B7, Size Tab: 0x2000
# Tile ID: 0x43B6, Size Tab: 0x2000
# Tile ID: 0x43B5, Size Tab: 0x2000
# Tile ID: 0x43B4, Size Tab: 0x2000
# Tile ID: 0x43B4, Size Tab: 0x1600
# Tile ID: 0x43B3, Size Tab: 0x2000
# Tile ID: 0x43B2, Size Tab: 0x2000
# Tile ID: 0x43B1, Size Tab: 0x2000
# Tile ID: 0x43B0, Size Tab: 0x2000
# Tile ID: 0x43B0, Size Tab: 0x0700
# Tile ID: 0x43AF, Size Tab: 0x2000
# Tile ID: 0x43AE, Size Tab: 0x1600
# Tile ID: 0x43AE, Size Tab: 0x2000
# Tile ID: 0x43AD, Size Tab: 0x2000
# Tile ID: 0x43AC, Size Tab: 0x2000
# Tile ID: 0x43AB, Size Tab: 0x2000
# Tile ID: 0x43AA, Size Tab: 0x2000
# Tile ID: 0x43A9, Size Tab: 0x2000
# Tile ID: 0x43A8, Size Tab: 0x0700
# Tile ID: 0x43A8, Size Tab: 0x1600
# Tile ID: 0x43A8, Size Tab: 0x2000
# Tile ID: 0x43A7, Size Tab: 0x2000
# Tile ID: 0x43A6, Size Tab: 0x2000
# Tile ID: 0x43A5, Size Tab: 0x2000
# Tile ID: 0x43A4, Size Tab: 0x2000
# Tile ID: 0x43A3, Size Tab: 0x2000
# Tile ID: 0x43A2, Size Tab: 0x1600
# Tile ID: 0x43A2, Size Tab: 0x2000
# Tile ID: 0x43A1, Size Tab: 0x2000
# Tile ID: 0x43A0, Size Tab: 0x2000
# Tile ID: 0x43A0, Size Tab: 0x0700
# Tile ID: 0x439F, Size Tab: 0x2000
# Tile ID: 0x439E, Size Tab: 0x2000
# Tile ID: 0x439D, Size Tab: 0x2000
# Tile ID: 0x439C, Size Tab: 0x1600
# Tile ID: 0x439C, Size Tab: 0x2000
# Tile ID: 0x439B, Size Tab: 0x2000
# Tile ID: 0x439A, Size Tab: 0x2000
# Tile ID: 0x4399, Size Tab: 0x2000
# Tile ID: 0x4398, Size Tab: 0x0700
# Tile ID: 0x4398, Size Tab: 0x2000
# Tile ID: 0x4397, Size Tab: 0x2000
# Tile ID: 0x4396, Size Tab: 0x1600
# Tile ID: 0x4396, Size Tab: 0x2000
# Tile ID: 0x4395, Size Tab: 0x2000
# Tile ID: 0x4394, Size Tab: 0x2000
# Tile ID: 0x4393, Size Tab: 0x2000
# Tile ID: 0x4392, Size Tab: 0x2000
# Tile ID: 0x4391, Size Tab: 0x2000
# Tile ID: 0x4390, Size Tab: 0x1600
# Tile ID: 0x4390, Size Tab: 0x2000
# Tile ID: 0x4390, Size Tab: 0x0700
# Tile ID: 0x438F, Size Tab: 0x2000
# Tile ID: 0x438E, Size Tab: 0x2000
# Tile ID: 0x438D, Size Tab: 0x2000
# Tile ID: 0x438C, Size Tab: 0x2000
# Tile ID: 0x438B, Size Tab: 0x2000
# Tile ID: 0x438A, Size Tab: 0x1600
# Tile ID: 0x438A, Size Tab: 0x2000
# Tile ID: 0x4389, Size Tab: 0x2000
# Tile ID: 0x4388, Size Tab: 0x0700
# Tile ID: 0x4388, Size Tab: 0x2000
# Tile ID: 0x4387, Size Tab: 0x2000
# Tile ID: 0x4386, Size Tab: 0x2000
# Tile ID: 0x4385, Size Tab: 0x2000
# Tile ID: 0x4384, Size Tab: 0x2000
# Tile ID: 0x4384, Size Tab: 0x1600
# Tile ID: 0x4383, Size Tab: 0x2000
# Tile ID: 0x4382, Size Tab: 0x2000
# Tile ID: 0x4381, Size Tab: 0x2000
# Tile ID: 0x4380, Size Tab: 0x2000
# Tile ID: 0x4380, Size Tab: 0x0700
# Tile ID: 0x437F, Size Tab: 0x2000
# Tile ID: 0x437E, Size Tab: 0x1600
# Tile ID: 0x437E, Size Tab: 0x2000
# Tile ID: 0x437D, Size Tab: 0x2000
# Tile ID: 0x437C, Size Tab: 0x2000
# Tile ID: 0x437B, Size Tab: 0x2000
# Tile ID: 0x437A, Size Tab: 0x2000
# Tile ID: 0x4379, Size Tab: 0x2000
# Tile ID: 0x4378, Size Tab: 0x0700
# Tile ID: 0x4378, Size Tab: 0x1600
# Tile ID: 0x4378, Size Tab: 0x2000
# Tile ID: 0x4377, Size Tab: 0x2000
# Tile ID: 0x4376, Size Tab: 0x2000
# Tile ID: 0x4375, Size Tab: 0x2000
# Tile ID: 0x4374, Size Tab: 0x2000
# Tile ID: 0x4373, Size Tab: 0x2000
# Tile ID: 0x4372, Size Tab: 0x2000
# Tile ID: 0x4372, Size Tab: 0x1600
# Tile ID: 0x4371, Size Tab: 0x2000
# Tile ID: 0x4370, Size Tab: 0x2000
# Tile ID: 0x4370, Size Tab: 0x0700
# Tile ID: 0x436F, Size Tab: 0x2000
# Tile ID: 0x436E, Size Tab: 0x2000
# Tile ID: 0x436D, Size Tab: 0x2000
# Tile ID: 0x436C, Size Tab: 0x1600
# Tile ID: 0x436C, Size Tab: 0x2000
# Tile ID: 0x436B, Size Tab: 0x2000
# Tile ID: 0x436A, Size Tab: 0x2000
# Tile ID: 0x4369, Size Tab: 0x2000
# Tile ID: 0x4368, Size Tab: 0x2000
# Tile ID: 0x4368, Size Tab: 0x0700
# Tile ID: 0x4367, Size Tab: 0x2000
# Tile ID: 0x4366, Size Tab: 0x1600
# Tile ID: 0x4366, Size Tab: 0x2000
# Tile ID: 0x4365, Size Tab: 0x2000
# Tile ID: 0x4364, Size Tab: 0x2000
# Tile ID: 0x4363, Size Tab: 0x2000
# Tile ID: 0x4362, Size Tab: 0x2000
# Tile ID: 0x4361, Size Tab: 0x2000
# Tile ID: 0x4360, Size Tab: 0x1600
# Tile ID: 0x4360, Size Tab: 0x2000
# Tile ID: 0x4360, Size Tab: 0x0700
# Tile ID: 0x435F, Size Tab: 0x2000
# Tile ID: 0x435E, Size Tab: 0x2000
# Tile ID: 0x435D, Size Tab: 0x2000
# Tile ID: 0x435C, Size Tab: 0x2000
# Tile ID: 0x435B, Size Tab: 0x2000
# Tile ID: 0x435A, Size Tab: 0x1600
# Tile ID: 0x435A, Size Tab: 0x2000
# Tile ID: 0x4359, Size Tab: 0x2000
# Tile ID: 0x4358, Size Tab: 0x0700
# Tile ID: 0x4354, Size Tab: 0x1600
# Tile ID: 0x4350, Size Tab: 0x0700
# Tile ID: 0x434E, Size Tab: 0x1600
# Tile ID: 0x434E, Size Tab: 0x2400
# Tile ID: 0x434C, Size Tab: 0x2400
# Tile ID: 0x434A, Size Tab: 0x2400
# Tile ID: 0x4348, Size Tab: 0x0700
# Tile ID: 0x4348, Size Tab: 0x1600
# Tile ID: 0x4348, Size Tab: 0x2400
# Tile ID: 0x4346, Size Tab: 0x2400
# Tile ID: 0x4344, Size Tab: 0x2400
# Tile ID: 0x4342, Size Tab: 0x2400
# Tile ID: 0x4342, Size Tab: 0x1600
# Tile ID: 0x4340, Size Tab: 0x0700
# Tile ID: 0x4340, Size Tab: 0x2400
# Tile ID: 0x433E, Size Tab: 0x2400
# Tile ID: 0x433C, Size Tab: 0x1600
# Tile ID: 0x433C, Size Tab: 0x2400
# Tile ID: 0x433A, Size Tab: 0x2400
# Tile ID: 0x4338, Size Tab: 0x0700
# Tile ID: 0x4338, Size Tab: 0x2400
# Tile ID: 0x4336, Size Tab: 0x2400
# Tile ID: 0x4336, Size Tab: 0x1600
# Tile ID: 0x4334, Size Tab: 0x2400
# Tile ID: 0x4332, Size Tab: 0x2400
# Tile ID: 0x4330, Size Tab: 0x0700
# Tile ID: 0x4330, Size Tab: 0x1600
# Tile ID: 0x4330, Size Tab: 0x2400
# Tile ID: 0x432E, Size Tab: 0x2400
# Tile ID: 0x432C, Size Tab: 0x2400
# Tile ID: 0x432A, Size Tab: 0x1600
# Tile ID: 0x432A, Size Tab: 0x2400
# Tile ID: 0x4328, Size Tab: 0x0700
# Tile ID: 0x4328, Size Tab: 0x2400
# Tile ID: 0x4326, Size Tab: 0x2400
# Tile ID: 0x4324, Size Tab: 0x1600
# Tile ID: 0x4324, Size Tab: 0x2400
# Tile ID: 0x4322, Size Tab: 0x2400
# Tile ID: 0x4320, Size Tab: 0x0700
# Tile ID: 0x4320, Size Tab: 0x2400
# Tile ID: 0x431E, Size Tab: 0x1600
# Tile ID: 0x431E, Size Tab: 0x2400
# Tile ID: 0x431C, Size Tab: 0x2400
# Tile ID: 0x431A, Size Tab: 0x2400
# Tile ID: 0x4318, Size Tab: 0x1600
# Tile ID: 0x4318, Size Tab: 0x2400
# Tile ID: 0x4318, Size Tab: 0x0700
# Tile ID: 0x4316, Size Tab: 0x2400
# Tile ID: 0x4314, Size Tab: 0x2400
# Tile ID: 0x4312, Size Tab: 0x1600
# Tile ID: 0x4312, Size Tab: 0x2400
# Tile ID: 0x4310, Size Tab: 0x2400
# Tile ID: 0x4310, Size Tab: 0x0700
# Tile ID: 0x430E, Size Tab: 0x2400
# Tile ID: 0x430C, Size Tab: 0x1600
# Tile ID: 0x430C, Size Tab: 0x2400
# Tile ID: 0x430A, Size Tab: 0x2400
# Tile ID: 0x4308, Size Tab: 0x2400
# Tile ID: 0x4308, Size Tab: 0x0700
# Tile ID: 0x4306, Size Tab: 0x1600
# Tile ID: 0x4306, Size Tab: 0x2400
# Tile ID: 0x4304, Size Tab: 0x2400
# Tile ID: 0x4302, Size Tab: 0x2400
# Tile ID: 0x4300, Size Tab: 0x0700
# Tile ID: 0x4300, Size Tab: 0x1600
# Tile ID: 0x4300, Size Tab: 0x2400
# Tile ID: 0x42FE, Size Tab: 0x2400
# Tile ID: 0x42FC, Size Tab: 0x2400
# Tile ID: 0x42FA, Size Tab: 0x1600
# Tile ID: 0x42FA, Size Tab: 0x2400
# Tile ID: 0x42F8, Size Tab: 0x2400
# Tile ID: 0x42F8, Size Tab: 0x0700
# Tile ID: 0x42F6, Size Tab: 0x2400
# Tile ID: 0x42F4, Size Tab: 0x1600
# Tile ID: 0x42F4, Size Tab: 0x2400
# Tile ID: 0x42F2, Size Tab: 0x2400
# Tile ID: 0x42F0, Size Tab: 0x0700
# Tile ID: 0x42F0, Size Tab: 0x2400
# Tile ID: 0x42EE, Size Tab: 0x1600
# Tile ID: 0x42EE, Size Tab: 0x2400
# Tile ID: 0x42EC, Size Tab: 0x2400
# Tile ID: 0x42EA, Size Tab: 0x2400
# Tile ID: 0x42E8, Size Tab: 0x1600
# Tile ID: 0x42E8, Size Tab: 0x2400
# Tile ID: 0x42E8, Size Tab: 0x0700
# Tile ID: 0x42E6, Size Tab: 0x2400
# Tile ID: 0x42E4, Size Tab: 0x2400
# Tile ID: 0x42E2, Size Tab: 0x1600
# Tile ID: 0x42E0, Size Tab: 0x0700
# Tile ID: 0x42E0, Size Tab: 0x2400
# Tile ID: 0x42DE, Size Tab: 0x2400
# Tile ID: 0x42DC, Size Tab: 0x1600
# Tile ID: 0x42DC, Size Tab: 0x2400
# Tile ID: 0x42DA, Size Tab: 0x2400
# Tile ID: 0x42D8, Size Tab: 0x2400
# Tile ID: 0x42D8, Size Tab: 0x0700
# Tile ID: 0x42D6, Size Tab: 0x1600
# Tile ID: 0x42D6, Size Tab: 0x2400
# Tile ID: 0x42D4, Size Tab: 0x2400
# Tile ID: 0x42D2, Size Tab: 0x2400
# Tile ID: 0x42D0, Size Tab: 0x0700
# Tile ID: 0x42D0, Size Tab: 0x1600
# Tile ID: 0x42D0, Size Tab: 0x2400
# Tile ID: 0x42CE, Size Tab: 0x2400
# Tile ID: 0x42CC, Size Tab: 0x2400
# Tile ID: 0x42CA, Size Tab: 0x2400
# Tile ID: 0x42CA, Size Tab: 0x1600
# Tile ID: 0x42C8, Size Tab: 0x2400
# Tile ID: 0x42C8, Size Tab: 0x0700
# Tile ID: 0x42C6, Size Tab: 0x2400
# Tile ID: 0x42C4, Size Tab: 0x1600
# Tile ID: 0x42C4, Size Tab: 0x2400
# Tile ID: 0x42C2, Size Tab: 0x2400
# Tile ID: 0x42C0, Size Tab: 0x0700
# Tile ID: 0x42C0, Size Tab: 0x2400
# Tile ID: 0x42BE, Size Tab: 0x1600
# Tile ID: 0x42BE, Size Tab: 0x2400
# Tile ID: 0x42BC, Size Tab: 0x2400
# Tile ID: 0x42BA, Size Tab: 0x2400
# Tile ID: 0x42B8, Size Tab: 0x2400
# Tile ID: 0x42B8, Size Tab: 0x0700
# Tile ID: 0x42B8, Size Tab: 0x1600
# Tile ID: 0x42B6, Size Tab: 0x2400
# Tile ID: 0x42B4, Size Tab: 0x2400
# Tile ID: 0x42B2, Size Tab: 0x1600
# Tile ID: 0x42B2, Size Tab: 0x2400
# Tile ID: 0x42B0, Size Tab: 0x0700
# Tile ID: 0x42B0, Size Tab: 0x2400
# Tile ID: 0x42AE, Size Tab: 0x2400
# Tile ID: 0x42AC, Size Tab: 0x2400
# Tile ID: 0x42AC, Size Tab: 0x1600
# Tile ID: 0x42AA, Size Tab: 0x2400
# Tile ID: 0x42A8, Size Tab: 0x2400
# Tile ID: 0x42A8, Size Tab: 0x0700
# Tile ID: 0x42A6, Size Tab: 0x2400
# Tile ID: 0x42A6, Size Tab: 0x1600
# Tile ID: 0x42A4, Size Tab: 0x2400
# Tile ID: 0x42A2, Size Tab: 0x2400
# Tile ID: 0x42A0, Size Tab: 0x0700
# Tile ID: 0x42A0, Size Tab: 0x1600
# Tile ID: 0x42A0, Size Tab: 0x2400
# Tile ID: 0x429E, Size Tab: 0x2400
# Tile ID: 0x429C, Size Tab: 0x2400
# Tile ID: 0x429A, Size Tab: 0x2400
# Tile ID: 0x429A, Size Tab: 0x1600
# Tile ID: 0x4298, Size Tab: 0x0700
# Tile ID: 0x4298, Size Tab: 0x2400
# Tile ID: 0x4296, Size Tab: 0x2400
# Tile ID: 0x4294, Size Tab: 0x1600
# Tile ID: 0x4294, Size Tab: 0x2400
# Tile ID: 0x4292, Size Tab: 0x2400
# Tile ID: 0x4290, Size Tab: 0x0700
# Tile ID: 0x4290, Size Tab: 0x2400
# Tile ID: 0x428E, Size Tab: 0x1600
# Tile ID: 0x428E, Size Tab: 0x2400
# Tile ID: 0x428C, Size Tab: 0x2400
# Tile ID: 0x428A, Size Tab: 0x2400
# Tile ID: 0x4288, Size Tab: 0x2400
# Tile ID: 0x4288, Size Tab: 0x1600
# Tile ID: 0x4288, Size Tab: 0x0700
# Tile ID: 0x4286, Size Tab: 0x2400
# Tile ID: 0x4284, Size Tab: 0x2400
# Tile ID: 0x4282, Size Tab: 0x2400
# Tile ID: 0x4282, Size Tab: 0x1600
# Tile ID: 0x4280, Size Tab: 0x2400
# Tile ID: 0x4280, Size Tab: 0x0700
# Tile ID: 0x427E, Size Tab: 0x2400
# Tile ID: 0x427C, Size Tab: 0x2400
# Tile ID: 0x427C, Size Tab: 0x1600
# Tile ID: 0x427A, Size Tab: 0x2400
# Tile ID: 0x4278, Size Tab: 0x2400
# Tile ID: 0x4278, Size Tab: 0x0700
# Tile ID: 0x4276, Size Tab: 0x1600
# Tile ID: 0x4276, Size Tab: 0x2400
# Tile ID: 0x4272, Size Tab: 0x2400
# Tile ID: 0x4270, Size Tab: 0x1600
# Tile ID: 0x4270, Size Tab: 0x0700
# Tile ID: 0x426E, Size Tab: 0x2400
# Tile ID: 0x426A, Size Tab: 0x1600
# Tile ID: 0x426A, Size Tab: 0x2400
# Tile ID: 0x4268, Size Tab: 0x0700
# Tile ID: 0x4264, Size Tab: 0x1600
# Tile ID: 0x4260, Size Tab: 0x0700
# Tile ID: 0x4260, Size Tab: 0x2400
# Tile ID: 0x425E, Size Tab: 0x2400
# Tile ID: 0x425E, Size Tab: 0x1600
# Tile ID: 0x425C, Size Tab: 0x2400
# Tile ID: 0x425A, Size Tab: 0x2400
# Tile ID: 0x4258, Size Tab: 0x0700
# Tile ID: 0x4258, Size Tab: 0x1600
# Tile ID: 0x4258, Size Tab: 0x2400
# Tile ID: 0x4256, Size Tab: 0x2400
# Tile ID: 0x4254, Size Tab: 0x2400
# Tile ID: 0x4252, Size Tab: 0x1600
# Tile ID: 0x4252, Size Tab: 0x2400
# Tile ID: 0x4250, Size Tab: 0x0700
# Tile ID: 0x4250, Size Tab: 0x2400
# Tile ID: 0x424E, Size Tab: 0x2400
# Tile ID: 0x424C, Size Tab: 0x1600
# Tile ID: 0x424C, Size Tab: 0x2400
# Tile ID: 0x424A, Size Tab: 0x2400
# Tile ID: 0x4248, Size Tab: 0x0700
# Tile ID: 0x4248, Size Tab: 0x2400
# Tile ID: 0x4246, Size Tab: 0x1600
# Tile ID: 0x4246, Size Tab: 0x2400
# Tile ID: 0x4244, Size Tab: 0x2400
# Tile ID: 0x4242, Size Tab: 0x2400
# Tile ID: 0x4240, Size Tab: 0x1600
# Tile ID: 0x4240, Size Tab: 0x2400
# Tile ID: 0x4240, Size Tab: 0x0700
# Tile ID: 0x423E, Size Tab: 0x2400
# Tile ID: 0x423C, Size Tab: 0x2400
# Tile ID: 0x423A, Size Tab: 0x1600
# Tile ID: 0x423A, Size Tab: 0x2400
# Tile ID: 0x4238, Size Tab: 0x2400
# Tile ID: 0x4238, Size Tab: 0x0700
# Tile ID: 0x4236, Size Tab: 0x2400
# Tile ID: 0x4234, Size Tab: 0x2400
# Tile ID: 0x4234, Size Tab: 0x1600
# Tile ID: 0x4232, Size Tab: 0x2400
# Tile ID: 0x4230, Size Tab: 0x2400
# Tile ID: 0x4230, Size Tab: 0x0700
# Tile ID: 0x422E, Size Tab: 0x1600
# Tile ID: 0x422E, Size Tab: 0x2400
# Tile ID: 0x422C, Size Tab: 0x2400
# Tile ID: 0x422A, Size Tab: 0x2400
# Tile ID: 0x4228, Size Tab: 0x1600
# Tile ID: 0x4228, Size Tab: 0x2400
# Tile ID: 0x4228, Size Tab: 0x0700
# Tile ID: 0x4226, Size Tab: 0x2400
# Tile ID: 0x4224, Size Tab: 0x2400
# Tile ID: 0x4222, Size Tab: 0x1600
# Tile ID: 0x4222, Size Tab: 0x2400
# Tile ID: 0x4220, Size Tab: 0x2400
# Tile ID: 0x4220, Size Tab: 0x0700
# Tile ID: 0x421E, Size Tab: 0x2400
# Tile ID: 0x421C, Size Tab: 0x2400
# Tile ID: 0x4218, Size Tab: 0x0700
# Tile ID: 0x4210, Size Tab: 0x1600
# Tile ID: 0x4210, Size Tab: 0x0700
# Tile ID: 0x420D, Size Tab: 0x2800
# Tile ID: 0x420A, Size Tab: 0x2800
# Tile ID: 0x420A, Size Tab: 0x1600
# Tile ID: 0x4208, Size Tab: 0x0700
# Tile ID: 0x4207, Size Tab: 0x2800
# Tile ID: 0x4204, Size Tab: 0x1600
# Tile ID: 0x4204, Size Tab: 0x2800
# Tile ID: 0x4201, Size Tab: 0x2800
# Tile ID: 0x4200, Size Tab: 0x0700
# Tile ID: 0x41FE, Size Tab: 0x1600
# Tile ID: 0x41FE, Size Tab: 0x2800
# Tile ID: 0x41FB, Size Tab: 0x2800
# Tile ID: 0x41F8, Size Tab: 0x0700
# Tile ID: 0x41F8, Size Tab: 0x1600
# Tile ID: 0x41F8, Size Tab: 0x2800
# Tile ID: 0x41F5, Size Tab: 0x2800
# Tile ID: 0x41F2, Size Tab: 0x2800
# Tile ID: 0x41F2, Size Tab: 0x1600
# Tile ID: 0x41F0, Size Tab: 0x0700
# Tile ID: 0x41EF, Size Tab: 0x2800
# Tile ID: 0x41EC, Size Tab: 0x1600
# Tile ID: 0x41EC, Size Tab: 0x2800
# Tile ID: 0x41E9, Size Tab: 0x2800
# Tile ID: 0x41E8, Size Tab: 0x0700
# Tile ID: 0x41E6, Size Tab: 0x1600
# Tile ID: 0x41E6, Size Tab: 0x2800
# Tile ID: 0x41E0, Size Tab: 0x1600
# Tile ID: 0x41E0, Size Tab: 0x2800
# Tile ID: 0x41E0, Size Tab: 0x0700
# Tile ID: 0x41DD, Size Tab: 0x2800
# Tile ID: 0x41DA, Size Tab: 0x1600
# Tile ID: 0x41DA, Size Tab: 0x2800
# Tile ID: 0x41D8, Size Tab: 0x0700
# Tile ID: 0x41D7, Size Tab: 0x2800
# Tile ID: 0x41D4, Size Tab: 0x2800
# Tile ID: 0x41D4, Size Tab: 0x1600
# Tile ID: 0x41D1, Size Tab: 0x2800
# Tile ID: 0x41D0, Size Tab: 0x0700
# Tile ID: 0x41CE, Size Tab: 0x1600
# Tile ID: 0x41CE, Size Tab: 0x2800
# Tile ID: 0x41CB, Size Tab: 0x2800
# Tile ID: 0x41C8, Size Tab: 0x0700
# Tile ID: 0x41C8, Size Tab: 0x1600
# Tile ID: 0x41C8, Size Tab: 0x2800
# Tile ID: 0x41C5, Size Tab: 0x2800
# Tile ID: 0x41C2, Size Tab: 0x2800
# Tile ID: 0x41C2, Size Tab: 0x1600
# Tile ID: 0x41C0, Size Tab: 0x0700
# Tile ID: 0x41BF, Size Tab: 0x2800
# Tile ID: 0x41BC, Size Tab: 0x1600
# Tile ID: 0x41BC, Size Tab: 0x2800
# Tile ID: 0x41B9, Size Tab: 0x2800
# Tile ID: 0x41B8, Size Tab: 0x0700
# Tile ID: 0x41B6, Size Tab: 0x2800
# Tile ID: 0x41B6, Size Tab: 0x1600
# Tile ID: 0x41B3, Size Tab: 0x2800
# Tile ID: 0x41B0, Size Tab: 0x1600
# Tile ID: 0x41B0, Size Tab: 0x2800
# Tile ID: 0x41AD, Size Tab: 0x2800
# Tile ID: 0x41AA, Size Tab: 0x2800
# Tile ID: 0x41A7, Size Tab: 0x1A00
# Tile ID: 0x41A7, Size Tab: 0x2800
# Tile ID: 0x41A4, Size Tab: 0x2800
# Tile ID: 0x41A1, Size Tab: 0x2800
# Tile ID: 0x419E, Size Tab: 0x1A00
# Tile ID: 0x4198, Size Tab: 0x0700
# Tile ID: 0x4195, Size Tab: 0x2800
# Tile ID: 0x4195, Size Tab: 0x1A00
# Tile ID: 0x4192, Size Tab: 0x2800
# Tile ID: 0x4190, Size Tab: 0x0700
# Tile ID: 0x418F, Size Tab: 0x2800
# Tile ID: 0x418C, Size Tab: 0x2800
# Tile ID: 0x418C, Size Tab: 0x1A00
# Tile ID: 0x4189, Size Tab: 0x2800
# Tile ID: 0x4188, Size Tab: 0x0700
# Tile ID: 0x4186, Size Tab: 0x2800
# Tile ID: 0x4183, Size Tab: 0x1A00
# Tile ID: 0x4183, Size Tab: 0x2800
# Tile ID: 0x4180, Size Tab: 0x0700
# Tile ID: 0x4180, Size Tab: 0x2800
# Tile ID: 0x417C, Size Tab: 0x2C00
# Tile ID: 0x417A, Size Tab: 0x1A00
# Tile ID: 0x4178, Size Tab: 0x0700
# Tile ID: 0x4178, Size Tab: 0x2C00
# Tile ID: 0x4174, Size Tab: 0x2C00
# Tile ID: 0x4171, Size Tab: 0x1A00
# Tile ID: 0x4170, Size Tab: 0x0700
# Tile ID: 0x4170, Size Tab: 0x2C00
# Tile ID: 0x416C, Size Tab: 0x2C00
# Tile ID: 0x4168, Size Tab: 0x0700
# Tile ID: 0x4168, Size Tab: 0x1A00
# Tile ID: 0x4168, Size Tab: 0x2C00
# Tile ID: 0x4164, Size Tab: 0x2C00
# Tile ID: 0x4160, Size Tab: 0x0700
# Tile ID: 0x4160, Size Tab: 0x2C00
# Tile ID: 0x415F, Size Tab: 0x1A00
# Tile ID: 0x415C, Size Tab: 0x2C00
# Tile ID: 0x4158, Size Tab: 0x2C00
# Tile ID: 0x4158, Size Tab: 0x0700
# Tile ID: 0x4156, Size Tab: 0x1A00
# Tile ID: 0x4154, Size Tab: 0x2C00
# Tile ID: 0x4150, Size Tab: 0x0700
# Tile ID: 0x4150, Size Tab: 0x2C00
# Tile ID: 0x414D, Size Tab: 0x1A00
# Tile ID: 0x414C, Size Tab: 0x2C00
# Tile ID: 0x4148, Size Tab: 0x2C00
# Tile ID: 0x4148, Size Tab: 0x0700
# Tile ID: 0x4146, Size Tab: 0x2100
# Tile ID: 0x4144, Size Tab: 0x2100
# Tile ID: 0x4144, Size Tab: 0x1A00
# Tile ID: 0x4142, Size Tab: 0x2100
# Tile ID: 0x4140, Size Tab: 0x2100
# Tile ID: 0x4140, Size Tab: 0x0700
# Tile ID: 0x413E, Size Tab: 0x2100
# Tile ID: 0x413C, Size Tab: 0x2100
# Tile ID: 0x413B, Size Tab: 0x1A00
# Tile ID: 0x413A, Size Tab: 0x2100
# Tile ID: 0x4138, Size Tab: 0x2100
# Tile ID: 0x4138, Size Tab: 0x0700
# Tile ID: 0x4136, Size Tab: 0x2100
# Tile ID: 0x4134, Size Tab: 0x2100
# Tile ID: 0x4132, Size Tab: 0x1A00
# Tile ID: 0x4132, Size Tab: 0x2100
# Tile ID: 0x4130, Size Tab: 0x2100
# Tile ID: 0x4130, Size Tab: 0x0700
# Tile ID: 0x412E, Size Tab: 0x2100
# Tile ID: 0x412C, Size Tab: 0x2100
# Tile ID: 0x412A, Size Tab: 0x2100
# Tile ID: 0x4129, Size Tab: 0x1A00
# Tile ID: 0x4128, Size Tab: 0x2100
# Tile ID: 0x4128, Size Tab: 0x0700
# Tile ID: 0x4126, Size Tab: 0x2100
# Tile ID: 0x4126, Size Tab: 0x1000
# Tile ID: 0x4124, Size Tab: 0x2100
# Tile ID: 0x4122, Size Tab: 0x2100
# Tile ID: 0x4120, Size Tab: 0x2100
# Tile ID: 0x4120, Size Tab: 0x0700
# Tile ID: 0x4120, Size Tab: 0x1A00
# Tile ID: 0x411E, Size Tab: 0x2100
# Tile ID: 0x411C, Size Tab: 0x2100
# Tile ID: 0x411A, Size Tab: 0x2100
# Tile ID: 0x4118, Size Tab: 0x2100
# Tile ID: 0x4118, Size Tab: 0x0700
# Tile ID: 0x4117, Size Tab: 0x1A00
# Tile ID: 0x4116, Size Tab: 0x2100
# Tile ID: 0x4114, Size Tab: 0x2100
# Tile ID: 0x4112, Size Tab: 0x2100
# Tile ID: 0x4110, Size Tab: 0x2100
# Tile ID: 0x4110, Size Tab: 0x0700
# Tile ID: 0x410E, Size Tab: 0x2100
# Tile ID: 0x410E, Size Tab: 0x1A00
# Tile ID: 0x410C, Size Tab: 0x2100
# Tile ID: 0x410A, Size Tab: 0x2100
# Tile ID: 0x4108, Size Tab: 0x2100
# Tile ID: 0x4108, Size Tab: 0x0700
# Tile ID: 0x4106, Size Tab: 0x2100
# Tile ID: 0x4105, Size Tab: 0x1A00
# Tile ID: 0x4104, Size Tab: 0x2100
# Tile ID: 0x4102, Size Tab: 0x2100
# Tile ID: 0x4100, Size Tab: 0x2100
# Tile ID: 0x4100, Size Tab: 0x0700
# Tile ID: 0x40FE, Size Tab: 0x2100
# Tile ID: 0x40FC, Size Tab: 0x2100
# Tile ID: 0x40FA, Size Tab: 0x2100
# Tile ID: 0x40F8, Size Tab: 0x2100
# Tile ID: 0x40F8, Size Tab: 0x0700
# Tile ID: 0x40F6, Size Tab: 0x2100
# Tile ID: 0x40F4, Size Tab: 0x2100
# Tile ID: 0x40F2, Size Tab: 0x2100
# Tile ID: 0x40F0, Size Tab: 0x0700
# Tile ID: 0x40F0, Size Tab: 0x2100
# Tile ID: 0x40EE, Size Tab: 0x2100
# Tile ID: 0x40EC, Size Tab: 0x2100
# Tile ID: 0x40EA, Size Tab: 0x2100
# Tile ID: 0x40E8, Size Tab: 0x2100
# Tile ID: 0x40E8, Size Tab: 0x0700
# Tile ID: 0x40E6, Size Tab: 0x2100
# Tile ID: 0x40E4, Size Tab: 0x2100
# Tile ID: 0x40E2, Size Tab: 0x2100
# Tile ID: 0x40E1, Size Tab: 0x1A00
# Tile ID: 0x40E0, Size Tab: 0x0700
# Tile ID: 0x40E0, Size Tab: 0x2100
# Tile ID: 0x40DE, Size Tab: 0x2100
# Tile ID: 0x40DC, Size Tab: 0x2100
# Tile ID: 0x40DA, Size Tab: 0x2100
# Tile ID: 0x40D8, Size Tab: 0x2100
# Tile ID: 0x40D8, Size Tab: 0x0700
# Tile ID: 0x40D8, Size Tab: 0x1A00
# Tile ID: 0x40D6, Size Tab: 0x2100
# Tile ID: 0x40D4, Size Tab: 0x2100
# Tile ID: 0x40D2, Size Tab: 0x2100
# Tile ID: 0x40D0, Size Tab: 0x0700
# Tile ID: 0x40D0, Size Tab: 0x2100
# Tile ID: 0x40CF, Size Tab: 0x1A00
# Tile ID: 0x40CE, Size Tab: 0x2100
# Tile ID: 0x40CC, Size Tab: 0x2100
# Tile ID: 0x40C9, Size Tab: 0x2000
# Tile ID: 0x40C8, Size Tab: 0x2100
# Tile ID: 0x40C8, Size Tab: 0x0700
# Tile ID: 0x40C6, Size Tab: 0x1A00
# Tile ID: 0x40C6, Size Tab: 0x2100
# Tile ID: 0x40C4, Size Tab: 0x2100
# Tile ID: 0x40C2, Size Tab: 0x2100
# Tile ID: 0x40C0, Size Tab: 0x2100
# Tile ID: 0x40C0, Size Tab: 0x0700
# Tile ID: 0x40BE, Size Tab: 0x2100
# Tile ID: 0x40BD, Size Tab: 0x1A00
# Tile ID: 0x40BC, Size Tab: 0x2100
# Tile ID: 0x40BA, Size Tab: 0x2100
# Tile ID: 0x40B8, Size Tab: 0x2100
# Tile ID: 0x40B8, Size Tab: 0x0700
# Tile ID: 0x40B6, Size Tab: 0x2100
# Tile ID: 0x40B4, Size Tab: 0x1A00
# Tile ID: 0x40B4, Size Tab: 0x2100
# Tile ID: 0x40B2, Size Tab: 0x2100
# Tile ID: 0x40B0, Size Tab: 0x0700
# Tile ID: 0x40B0, Size Tab: 0x2100
# Tile ID: 0x40AE, Size Tab: 0x2100
# Tile ID: 0x40AC, Size Tab: 0x2100
# Tile ID: 0x40AB, Size Tab: 0x1A00
# Tile ID: 0x40AA, Size Tab: 0x2100
# Tile ID: 0x40A8, Size Tab: 0x2100
# Tile ID: 0x40A8, Size Tab: 0x0700
# Tile ID: 0x40A6, Size Tab: 0x2100
# Tile ID: 0x40A4, Size Tab: 0x2100
# Tile ID: 0x40A2, Size Tab: 0x1A00
# Tile ID: 0x40A2, Size Tab: 0x2100
# Tile ID: 0x40A0, Size Tab: 0x0700
# Tile ID: 0x40A0, Size Tab: 0x2100
# Tile ID: 0x409E, Size Tab: 0x2100
# Tile ID: 0x409C, Size Tab: 0x2100
# Tile ID: 0x409A, Size Tab: 0x2100
# Tile ID: 0x4099, Size Tab: 0x1A00
# Tile ID: 0x4098, Size Tab: 0x2100
# Tile ID: 0x4098, Size Tab: 0x0700
# Tile ID: 0x4096, Size Tab: 0x2100
# Tile ID: 0x4094, Size Tab: 0x2100
# Tile ID: 0x4092, Size Tab: 0x2100
# Tile ID: 0x4090, Size Tab: 0x0700
# Tile ID: 0x4090, Size Tab: 0x1A00
# Tile ID: 0x4090, Size Tab: 0x2100
# Tile ID: 0x408E, Size Tab: 0x2100
# Tile ID: 0x408C, Size Tab: 0x2100
# Tile ID: 0x408C, Size Tab: 0x2000
# Tile ID: 0x408A, Size Tab: 0x2100
# Tile ID: 0x4088, Size Tab: 0x2100
# Tile ID: 0x4088, Size Tab: 0x0700
# Tile ID: 0x4087, Size Tab: 0x1A00
# Tile ID: 0x4086, Size Tab: 0x2100
# Tile ID: 0x4084, Size Tab: 0x2100
# Tile ID: 0x4082, Size Tab: 0x2100
# Tile ID: 0x4080, Size Tab: 0x0700
# Tile ID: 0x4080, Size Tab: 0x2100
# Tile ID: 0x407E, Size Tab: 0x1A00
# Tile ID: 0x407E, Size Tab: 0x2100
# Tile ID: 0x407C, Size Tab: 0x2100
# Tile ID: 0x407A, Size Tab: 0x2100
# Tile ID: 0x4078, Size Tab: 0x2100
# Tile ID: 0x4078, Size Tab: 0x0700
# Tile ID: 0x4076, Size Tab: 0x2100
# Tile ID: 0x4075, Size Tab: 0x1A00
# Tile ID: 0x4074, Size Tab: 0x2100
# Tile ID: 0x4072, Size Tab: 0x2100
# Tile ID: 0x4070, Size Tab: 0x2100
# Tile ID: 0x406E, Size Tab: 0x2100
# Tile ID: 0x406C, Size Tab: 0x2100
# Tile ID: 0x406C, Size Tab: 0x0B00
# Tile ID: 0x406C, Size Tab: 0x1A00
# Tile ID: 0x406A, Size Tab: 0x2100
# Tile ID: 0x4068, Size Tab: 0x2100
# Tile ID: 0x4066, Size Tab: 0x2100
# Tile ID: 0x4064, Size Tab: 0x2100
# Tile ID: 0x4063, Size Tab: 0x1A00
# Tile ID: 0x4062, Size Tab: 0x2100
# Tile ID: 0x4060, Size Tab: 0x0B00
# Tile ID: 0x4060, Size Tab: 0x2100
# Tile ID: 0x405E, Size Tab: 0x2100
# Tile ID: 0x405C, Size Tab: 0x2100
# Tile ID: 0x405A, Size Tab: 0x2100
# Tile ID: 0x405A, Size Tab: 0x1A00
# Tile ID: 0x4058, Size Tab: 0x2100
# Tile ID: 0x4056, Size Tab: 0x2100
# Tile ID: 0x4054, Size Tab: 0x0B00
# Tile ID: 0x4054, Size Tab: 0x2100
# Tile ID: 0x4052, Size Tab: 0x2100
# Tile ID: 0x4051, Size Tab: 0x1A00
# Tile ID: 0x4050, Size Tab: 0x2100
# Tile ID: 0x404E, Size Tab: 0x2100
# Tile ID: 0x404C, Size Tab: 0x2100
# Tile ID: 0x404A, Size Tab: 0x2100
# Tile ID: 0x4048, Size Tab: 0x2100
# Tile ID: 0x4048, Size Tab: 0x0B00
# Tile ID: 0x4048, Size Tab: 0x1A00
# Tile ID: 0x4044, Size Tab: 0x2100
# Tile ID: 0x4042, Size Tab: 0x2100
# Tile ID: 0x4040, Size Tab: 0x2100
# Tile ID: 0x403F, Size Tab: 0x1A00
# Tile ID: 0x403A, Size Tab: 0x2100
# Tile ID: 0x4038, Size Tab: 0x2100
# Tile ID: 0x4036, Size Tab: 0x2100
# Tile ID: 0x4036, Size Tab: 0x1A00
# Tile ID: 0x4034, Size Tab: 0x2100
# Tile ID: 0x4032, Size Tab: 0x2100
# Tile ID: 0x4030, Size Tab: 0x2100
# Tile ID: 0x4030, Size Tab: 0x0B00
# Tile ID: 0x402E, Size Tab: 0x2100
# Tile ID: 0x402D, Size Tab: 0x1A00
# Tile ID: 0x402C, Size Tab: 0x2100
# Tile ID: 0x402A, Size Tab: 0x2100
# Tile ID: 0x4028, Size Tab: 0x2100
# Tile ID: 0x4026, Size Tab: 0x2100
# Tile ID: 0x4024, Size Tab: 0x2100
# Tile ID: 0x4024, Size Tab: 0x0B00
# Tile ID: 0x4024, Size Tab: 0x1A00
# Tile ID: 0x4023, Size Tab: 0x2000
# Tile ID: 0x4022, Size Tab: 0x2100
# Tile ID: 0x4020, Size Tab: 0x2100
# Tile ID: 0x401E, Size Tab: 0x2100
# Tile ID: 0x401C, Size Tab: 0x2100
# Tile ID: 0x401B, Size Tab: 0x1A00
# Tile ID: 0x401A, Size Tab: 0x2100
# Tile ID: 0x4018, Size Tab: 0x2100
# Tile ID: 0x4018, Size Tab: 0x0B00
# Tile ID: 0x4016, Size Tab: 0x2100
# Tile ID: 0x4014, Size Tab: 0x2100
# Tile ID: 0x4012, Size Tab: 0x2100
# Tile ID: 0x4012, Size Tab: 0x1A00
# Tile ID: 0x4010, Size Tab: 0x2100
# Tile ID: 0x400E, Size Tab: 0x2100
# Tile ID: 0x400C, Size Tab: 0x0B00
# Tile ID: 0x400C, Size Tab: 0x2100
# Tile ID: 0x400A, Size Tab: 0x2100
# Tile ID: 0x4009, Size Tab: 0x1A00
# Tile ID: 0x4008, Size Tab: 0x2100
# Tile ID: 0x4006, Size Tab: 0x2100
# Tile ID: 0x4004, Size Tab: 0x2100
# Tile ID: 0x4002, Size Tab: 0x2100
# Tile ID: 0x4000, Size Tab: 0x0B00
# Tile ID: 0x4000, Size Tab: 0x1A00
# Tile ID: 0x4000, Size Tab: 0x2100
# Tile ID: 0x2F08, Size Tab: 0x1500
# Tile ID: 0x27EE, Size Tab: 0x0A00
# Tile ID: 0x27E5, Size Tab: 0x0A00
# Tile ID: 0x27DC, Size Tab: 0x0A00
# Tile ID: 0x27D3, Size Tab: 0x0A00
# Tile ID: 0x27CA, Size Tab: 0x0A00
# Tile ID: 0x27C1, Size Tab: 0x0A00
# Tile ID: 0x27B8, Size Tab: 0x0A00
# Tile ID: 0x2770, Size Tab: 0x0E00
# Tile ID: 0x2764, Size Tab: 0x0E00
# Tile ID: 0x2758, Size Tab: 0x0E00
# Tile ID: 0x274C, Size Tab: 0x0E00
# Tile ID: 0x2740, Size Tab: 0x0E00
# Tile ID: 0x2734, Size Tab: 0x0E00
# Tile ID: 0x2728, Size Tab: 0x0E00
# Tile ID: 0x271C, Size Tab: 0x0E00
# Tile ID: 0x2710, Size Tab: 0x0E00
# Tile ID: 0x2708, Size Tab: 0x1500
# Tile ID: 0x2704, Size Tab: 0x0E00
# Tile ID: 0x26F8, Size Tab: 0x0E00
# Tile ID: 0x26EC, Size Tab: 0x0E00
# Tile ID: 0x26E0, Size Tab: 0x0E00
# Tile ID: 0x26D4, Size Tab: 0x0E00
# Tile ID: 0x26C8, Size Tab: 0x0E00
# Tile ID: 0x26BC, Size Tab: 0x0E00
# Tile ID: 0x2504, Size Tab: 0x2000
# Tile ID: 0x24E0, Size Tab: 0x1D00
# Tile ID: 0x2352, Size Tab: 0x2400
# Tile ID: 0x2350, Size Tab: 0x2400
# Tile ID: 0x2262, Size Tab: 0x2400
# Tile ID: 0x20FC, Size Tab: 0x1A00
# Tile ID: 0x20F3, Size Tab: 0x1A00
# Tile ID: 0x20EA, Size Tab: 0x1A00
# Tile ID: 0x0FFA, Size Tab: 0x1100
# Tile ID: 0x0FF6, Size Tab: 0x1100
# Tile ID: 0x0F08, Size Tab: 0x1500
# Tile ID: 0x0F04, Size Tab: 0x1500
# Tile ID: 0x0DFA, Size Tab: 0x1900
# Tile ID: 0x0CDD, Size Tab: 0x1200
# Tile ID: 0x0C02, Size Tab: 0x2000
# Tile ID: 0x0C00, Size Tab: 0x2000
# Tile ID: 0x0BFE, Size Tab: 0x2000
# Tile ID: 0x0BFD, Size Tab: 0x2000
# Tile ID: 0x0BFC, Size Tab: 0x2000
# Tile ID: 0x0B57, Size Tab: 0x2000
# Tile ID: 0x0B56, Size Tab: 0x2000
# Tile ID: 0x0B54, Size Tab: 0x2000
# Tile ID: 0x0A1A, Size Tab: 0x2400
# Tile ID: 0x0A18, Size Tab: 0x2400
# Tile ID: 0x0A16, Size Tab: 0x2400
# Tile ID: 0x0A14, Size Tab: 0x2400
# Tile ID: 0x0A12, Size Tab: 0x2400
# Tile ID: 0x09E3, Size Tab: 0x2800
# Tile ID: 0x083C, Size Tab: 0x2100
# Tile ID: 0x083C, Size Tab: 0x0B00
# Tile ID: 0x07FC, Size Tab: 0x1100
# Tile ID: 0x07FA, Size Tab: 0x1100
# Tile ID: 0x07F8, Size Tab: 0x1100
# Tile ID: 0x07F6, Size Tab: 0x1100
# Tile ID: 0x07F4, Size Tab: 0x1100
# Tile ID: 0x07A8, Size Tab: 0x1500
# Tile ID: 0x07A0, Size Tab: 0x1500
# Tile ID: 0x079C, Size Tab: 0x1500
# Tile ID: 0x0794, Size Tab: 0x1500
# Tile ID: 0x0708, Size Tab: 0x1500
# Tile ID: 0x0704, Size Tab: 0x1500
# Tile ID: 0x05FA, Size Tab: 0x1900
# Tile ID: 0x055B, Size Tab: 0x2000
# Tile ID: 0x055A, Size Tab: 0x2000
# Tile ID: 0x0559, Size Tab: 0x2000
# Tile ID: 0x0557, Size Tab: 0x2000
# Tile ID: 0x0556, Size Tab: 0x2000
# Tile ID: 0x0553, Size Tab: 0x2000
# Tile ID: 0x0552, Size Tab: 0x2000
# Tile ID: 0x0550, Size Tab: 0x2000
# Tile ID: 0x054F, Size Tab: 0x2000
# Tile ID: 0x054D, Size Tab: 0x2000
# Tile ID: 0x054C, Size Tab: 0x2000
# Tile ID: 0x054B, Size Tab: 0x2000
# Tile ID: 0x054A, Size Tab: 0x2000
# Tile ID: 0x0548, Size Tab: 0x2000
# Tile ID: 0x0547, Size Tab: 0x2000
# Tile ID: 0x0545, Size Tab: 0x2000
# Tile ID: 0x04E9, Size Tab: 0x2000
# Tile ID: 0x04E4, Size Tab: 0x2000
# Tile ID: 0x04DD, Size Tab: 0x1200
# Tile ID: 0x0404, Size Tab: 0x2000
# Tile ID: 0x0403, Size Tab: 0x2000
# Tile ID: 0x0402, Size Tab: 0x2000
# Tile ID: 0x0401, Size Tab: 0x2000
# Tile ID: 0x0400, Size Tab: 0x2000
# Tile ID: 0x03FF, Size Tab: 0x2000
# Tile ID: 0x0358, Size Tab: 0x2000
# Tile ID: 0x0357, Size Tab: 0x2000
# Tile ID: 0x0356, Size Tab: 0x2000
# Tile ID: 0x0355, Size Tab: 0x2000
# Tile ID: 0x0354, Size Tab: 0x2000
# Tile ID: 0x02E2, Size Tab: 0x2400
# Tile ID: 0x021A, Size Tab: 0x2400
# Tile ID: 0x0218, Size Tab: 0x2400
# Tile ID: 0x0216, Size Tab: 0x2400
# Tile ID: 0x0214, Size Tab: 0x2400
# Tile ID: 0x0212, Size Tab: 0x2400
# Tile ID: 0x0210, Size Tab: 0x2400
# Tile ID: 0x01E3, Size Tab: 0x2800
# Tile ID: 0x00FC, Size Tab: 0x1A00
# Tile ID: 0x00F3, Size Tab: 0x1A00
# Tile ID: 0x00EA, Size Tab: 0x1A00
# Tile ID: 0x00CA, Size Tab: 0x2100
# Tile ID: 0x003C, Size Tab: 0x2100
# Tile ID: 0x003C, Size Tab: 0x0B00
